# %%
# ============================================================
# S3: ARTIFACT-CONDITIONED GATED FUSION STUDENT + KD
#
# Identical to S2 (KD from frozen PSG teacher), except the
# fusion mechanism changes from simple concatenation to an
# artifact-conditioned GATE:
#
#   Zmax EEG --> ZmaxEEGEncoder --> z (96-dim)  --\
#                                                   >-- Gate(z, e, artifact_weight)
#   E4       --> E4Encoder      --> e (96-dim)  --/         |
#                                                            v
#                                               fused = gate*z + (1-gate)*e
#                                                            |
#                                                            v
#                                                       Classifier
#
# Loss (still plain CE + KD -- artifact-WEIGHTED loss is S4,
# not this script):
#   L = L_CE + lambda_KD * L_KD
#
# UPDATED: uses the 3-way split (_train_subs.npy / _val_subs.npy /
# _test_subs.npy). Checkpoint selection uses VAL F1 every epoch;
# TEST is evaluated exactly once, after training.
#
# Compare against S2 (re-run on this same split) to isolate the
# effect of artifact-aware fusion alone.
# ============================================================

import os
import csv
import math
import random
import warnings
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from collections import Counter
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score
warnings.filterwarnings('ignore')

# ============================================================
# PATHS
# ============================================================
PSG_EEG_PATH      = r"D:\22\AA\preprocess\preprocessed_FFinal"
STUDENT_DATA_PATH = r"D:\22\AA\preprocess\preprocessed_student_zmax_e4"
SPLIT_PATH        = r"D:\22\AA\AA journal\preprocess\preprocessed_split_v2"
TEACHER_CKPT_DIR  = r"D:\22\AA\AA journal\evaluation\multiscale_plain_c7_valfixed"
EVAL_PATH         = r"D:\22\AA\AA journal\evaluation\teacher-student\s3_artifact_gated_kd"
os.makedirs(EVAL_PATH, exist_ok=True)

LABEL_NAMES = ["Wake", "N1", "N2", "N3", "REM"]
CONTEXT     = 7
WINDOW      = 2 * CONTEXT + 1
N_EPOCHS    = 30
BATCH_SIZE  = 64
SEEDS         = [42, 123, 256, 789, 999]
TEACHER_SEEDS = [42, 123, 256, 789, 999]

T_D_MODEL = 128
T_DROPOUT = 0.4
T_N_HEADS = 4

S_D_MODEL = 96
S_DROPOUT = 0.3

KD_LAMBDA      = 0.5
KD_TEMPERATURE = 4.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device        : {device}")
print(f"S3: Artifact-conditioned gated fusion + KD (no artifact loss weighting yet)")
print(f"KD lambda     : {KD_LAMBDA}   Temperature: {KD_TEMPERATURE}")
print(f"Output        : {EVAL_PATH}")


# ============================================================
# ============  TEACHER ARCHITECTURE (frozen)  ================
# ============================================================
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=8):
        super().__init__()
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Sequential(
            nn.Linear(channels, channels // reduction), nn.ReLU(),
            nn.Linear(channels // reduction, channels), nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _ = x.shape
        s = self.pool(x).view(b, c)
        s = self.fc(s).view(b, c, 1)
        return x * s


class MultiScaleCNN(nn.Module):
    def __init__(self, in_ch=3, d_model=T_D_MODEL, dropout=T_DROPOUT):
        super().__init__()
        mid = d_model // 4

        def time_branch(kernel):
            return nn.Sequential(
                nn.Conv1d(in_ch, mid, kernel_size=kernel, stride=6, padding=kernel // 2),
                nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(4, 4),
                nn.Conv1d(mid, mid, kernel_size=8, padding=4),
                nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(2, 2),
                nn.Dropout(dropout),
            )

        self.small  = time_branch(25)
        self.medium = time_branch(50)
        self.large  = time_branch(100)

        self.spectral = nn.Sequential(
            nn.Conv1d(in_ch, mid, kernel_size=25, stride=6, padding=12),
            nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(4, 4),
            nn.Conv1d(mid, mid, kernel_size=8, padding=4),
            nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(2, 2),
            nn.Dropout(dropout),
        )

        with torch.no_grad():
            dummy = torch.zeros(1, in_ch, 3000)
            L_s = self.small(dummy).shape[2]
            L_m = self.medium(dummy).shape[2]
            L_l = self.large(dummy).shape[2]
            L_f = self.spectral(dummy).shape[2]

        target_L = min(L_s, L_m, L_l, L_f)
        self.pool_s = nn.AdaptiveAvgPool1d(target_L)
        self.pool_m = nn.AdaptiveAvgPool1d(target_L)
        self.pool_l = nn.AdaptiveAvgPool1d(target_L)
        self.pool_f = nn.AdaptiveAvgPool1d(target_L)
        self.out_len = target_L

        self.se = SEBlock(4 * mid)
        self.proj = nn.Sequential(
            nn.Conv1d(4 * mid, d_model, kernel_size=1),
            nn.BatchNorm1d(d_model), nn.GELU(),
        )

    def forward(self, x):
        fs = self.pool_s(self.small(x))
        fm = self.pool_m(self.medium(x))
        fl = self.pool_l(self.large(x))

        x_fft = torch.fft.rfft(x, dim=-1)
        x_mag = torch.abs(x_fft)
        if x_mag.shape[-1] < x.shape[-1]:
            pad = x.shape[-1] - x_mag.shape[-1]
            x_mag = F.pad(x_mag, (0, pad))
        else:
            x_mag = x_mag[..., :x.shape[-1]]
        ff = self.pool_f(self.spectral(x_mag))

        feat = torch.cat([fs, fm, fl, ff], dim=1)
        feat = self.se(feat)
        return self.proj(feat)


class BiLSTMTransformerBlock(nn.Module):
    def __init__(self, d_model=T_D_MODEL, n_heads=T_N_HEADS, dropout=T_DROPOUT):
        super().__init__()
        self.bilstm = nn.LSTM(
            d_model, d_model // 2, num_layers=1,
            batch_first=True, bidirectional=True
        )
        self.norm1 = nn.LayerNorm(d_model)
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=n_heads,
            dim_feedforward=d_model * 2, dropout=dropout,
            batch_first=True, activation='gelu'
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=1)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        lstm_out, _ = self.bilstm(x)
        x = self.norm1(x + lstm_out)
        attn_out = self.transformer(x)
        return self.norm2(x + attn_out)


class MultiScaleSleepNetPlain(nn.Module):
    """Teacher architecture -- identical to your trained checkpoints."""
    def __init__(self, in_ch=3, d_model=T_D_MODEL, n_layers=2,
                 dropout=T_DROPOUT, n_classes=5, context=CONTEXT):
        super().__init__()
        self.context = context
        self.d_model = d_model
        self.cnn = MultiScaleCNN(in_ch=in_ch, d_model=d_model, dropout=dropout)
        self.intra_blocks = nn.Sequential(*[
            BiLSTMTransformerBlock(d_model, dropout=dropout) for _ in range(n_layers)
        ])
        self.inter_pos = nn.Parameter(torch.randn(1, WINDOW, d_model) * 0.01)
        self.inter_blocks = nn.Sequential(*[
            BiLSTMTransformerBlock(d_model, dropout=dropout) for _ in range(n_layers)
        ])
        self.classifier = nn.Sequential(
            nn.LayerNorm(d_model), nn.Linear(d_model, 64), nn.GELU(),
            nn.Dropout(dropout), nn.Linear(64, n_classes),
        )

    def forward(self, x):
        B, W, C, T = x.shape
        cnn_out = self.cnn(x.view(B * W, C, T)).permute(0, 2, 1)
        intra = self.intra_blocks(cnn_out)
        epoch_feat = intra.mean(dim=1).view(B, W, self.d_model)
        inter = self.inter_blocks(epoch_feat + self.inter_pos)
        center = inter[:, self.context, :]
        return self.classifier(center)


# ============================================================
# ============  STUDENT ARCHITECTURE (gated fusion)  ===========
# ============================================================
class ZmaxEEGEncoder(nn.Module):
    def __init__(self, in_ch=2, d_model=S_D_MODEL, dropout=S_DROPOUT):
        super().__init__()
        mid = d_model // 2

        def branch(kernel):
            return nn.Sequential(
                nn.Conv1d(in_ch, mid, kernel_size=kernel, stride=4, padding=kernel // 2),
                nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(2, 2), nn.Dropout(dropout)
            )
        self.small, self.large = branch(15), branch(60)
        with torch.no_grad():
            dummy = torch.zeros(1, in_ch, 1920)
            L_s, L_l = self.small(dummy).shape[2], self.large(dummy).shape[2]
        target_L = min(L_s, L_l)
        self.pool_s = nn.AdaptiveAvgPool1d(target_L)
        self.pool_l = nn.AdaptiveAvgPool1d(target_L)
        self.proj = nn.Sequential(nn.Conv1d(2 * mid, d_model, kernel_size=1),
                                   nn.BatchNorm1d(d_model), nn.GELU())
        self.gru = nn.GRU(d_model, d_model // 2, batch_first=True, bidirectional=True)
        self.norm = nn.LayerNorm(d_model)

    def forward(self, x):
        fs, fl = self.pool_s(self.small(x)), self.pool_l(self.large(x))
        feat = self.proj(torch.cat([fs, fl], dim=1)).permute(0, 2, 1)
        gru_out, _ = self.gru(feat)
        return self.norm(feat.mean(dim=1) + gru_out.mean(dim=1))


class E4Encoder(nn.Module):
    def __init__(self, in_ch=3, d_model=S_D_MODEL, dropout=S_DROPOUT):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(in_ch, d_model // 2, kernel_size=15, stride=4, padding=7),
            nn.BatchNorm1d(d_model // 2), nn.GELU(), nn.MaxPool1d(2, 2),
            nn.Conv1d(d_model // 2, d_model, kernel_size=8, padding=4),
            nn.BatchNorm1d(d_model), nn.GELU(), nn.MaxPool1d(2, 2),
            nn.Dropout(dropout),
        )
        self.gru = nn.GRU(d_model, d_model // 2, batch_first=True, bidirectional=True)
        self.norm = nn.LayerNorm(d_model)

    def forward(self, x):
        feat = self.conv(x).permute(0, 2, 1)
        gru_out, _ = self.gru(feat)
        return self.norm(feat.mean(dim=1) + gru_out.mean(dim=1))


class ArtifactGatedFusion(nn.Module):
    """
    Gate conditioned on the per-epoch Zmax artifact quality score:
    noisy EEG epoch (low artifact_weight) -> gate leans toward E4;
    clean EEG (artifact_weight near 1.0)  -> gate leans toward EEG.
    """
    def __init__(self, d_model=S_D_MODEL):
        super().__init__()
        self.gate_fc = nn.Sequential(
            nn.Linear(d_model * 2 + 1, d_model // 2), nn.GELU(),
            nn.Linear(d_model // 2, 1), nn.Sigmoid()
        )

    def forward(self, zmax_embed, e4_embed, artifact_weight):
        aw = artifact_weight.unsqueeze(1)          # (B, 1)
        gate_in = torch.cat([zmax_embed, e4_embed, aw], dim=1)
        gate = self.gate_fc(gate_in)                # (B, 1) in [0,1]
        fused = gate * zmax_embed + (1 - gate) * e4_embed
        return fused, gate


class ArtifactGatedStudentModel(nn.Module):
    def __init__(self, d_model=S_D_MODEL, n_classes=5, dropout=S_DROPOUT):
        super().__init__()
        self.zmax_enc = ZmaxEEGEncoder(in_ch=2, d_model=d_model, dropout=dropout)
        self.e4_enc   = E4Encoder(in_ch=3, d_model=d_model, dropout=dropout)
        self.fusion   = ArtifactGatedFusion(d_model=d_model)
        self.classifier = nn.Sequential(
            nn.LayerNorm(d_model), nn.Linear(d_model, 64), nn.GELU(),
            nn.Dropout(dropout), nn.Linear(64, n_classes)
        )

    def forward(self, zmax_x, e4_x, artifact_weight):
        z = self.zmax_enc(zmax_x)
        e = self.e4_enc(e4_x)
        fused, gate = self.fusion(z, e, artifact_weight)
        logits = self.classifier(fused)
        return logits, gate


# ============================================================
# COMBINED DATASET (also returns artifact_weight for the gate)
# ============================================================
class KDDataset(Dataset):
    def __init__(self, subject_list, psg_path, student_path, context=CONTEXT):
        self.context = context
        self.data = []
        self.index = []

        skipped_mismatch = 0
        for sub in subject_list:
            psg_fp = os.path.join(psg_path, f"{sub}.npz")
            stu_fp = os.path.join(student_path, f"{sub}.npz")
            if not (os.path.exists(psg_fp) and os.path.exists(stu_fp)):
                continue

            with np.load(psg_fp) as d:
                eeg = d['eeg'][:, [0, 1], :]
                eog = d['eog'][:, [0], :]
                psg_signal = np.concatenate([eeg, eog], axis=1).astype(np.float32)
                psg_labels = d['labels'].copy()

            with np.load(stu_fp) as d:
                zmax_arr = d['zmax_eeg']
                e4_arr   = d['e4']
                stu_labels = d['labels'].copy()
                art_w = d['artifact_weight']

            n = min(len(psg_labels), len(stu_labels))
            if abs(len(psg_labels) - len(stu_labels)) > 5:
                skipped_mismatch += 1

            sub_idx = len(self.data)
            self.data.append((psg_signal, psg_labels, zmax_arr, e4_arr, art_w, stu_labels))
            for i in range(n):
                self.index.append((sub_idx, i, n))

        print(f"  Subjects loaded: {len(self.data)}  (large mismatches: {skipped_mismatch})")
        print(f"  Samples: {len(self.index):,}")

    def __len__(self):
        return len(self.index)

    def __getitem__(self, idx):
        sub_idx, center_i, n = self.index[idx]
        psg_signal, psg_labels, zmax_arr, e4_arr, art_w, stu_labels = self.data[sub_idx]

        window_epochs = []
        for offset in range(-self.context, self.context + 1):
            ei = max(0, min(n - 1, center_i + offset))
            window_epochs.append(psg_signal[ei])
        psg_x = np.stack(window_epochs, axis=0)

        ei = min(center_i, zmax_arr.shape[0] - 1, e4_arr.shape[0] - 1)
        zmax_x = zmax_arr[ei]
        e4_x   = e4_arr[ei]
        aw     = float(art_w[ei]) if ei < len(art_w) else 1.0

        y = int(stu_labels[center_i]) if center_i < len(stu_labels) else int(psg_labels[center_i])

        return (
            torch.FloatTensor(psg_x),
            torch.FloatTensor(zmax_x),
            torch.FloatTensor(e4_x),
            torch.tensor(aw, dtype=torch.float32),
            torch.tensor(y, dtype=torch.long),
        )


# ============================================================
# 3-WAY SPLIT + BUILD DATASETS
# ============================================================
_train_path = os.path.join(SPLIT_PATH, "_train_subs.npy")
_val_path   = os.path.join(SPLIT_PATH, "_val_subs.npy")
_test_path  = os.path.join(SPLIT_PATH, "_test_subs.npy")

for p, name in [(_train_path, "_train_subs.npy"),
                (_val_path,   "_val_subs.npy"),
                (_test_path,  "_test_subs.npy")]:
    if not os.path.exists(p):
        raise FileNotFoundError(f"{name} not found at {SPLIT_PATH}")

TRAIN_SUBS = np.load(_train_path, allow_pickle=True).tolist()
VAL_SUBS   = np.load(_val_path,   allow_pickle=True).tolist()
TEST_SUBS  = np.load(_test_path,  allow_pickle=True).tolist()

assert set(TRAIN_SUBS).isdisjoint(VAL_SUBS),  "TRAIN/VAL subject overlap!"
assert set(TRAIN_SUBS).isdisjoint(TEST_SUBS), "TRAIN/TEST subject overlap!"
assert set(VAL_SUBS).isdisjoint(TEST_SUBS),   "VAL/TEST subject overlap!"

print(f"Split loaded -> Train:{len(TRAIN_SUBS)}  Val:{len(VAL_SUBS)}  Test:{len(TEST_SUBS)}")

print("\nBuilding KD datasets...")
print("Train:")
train_ds = KDDataset(TRAIN_SUBS, PSG_EEG_PATH, STUDENT_DATA_PATH)
print("Val:")
val_ds   = KDDataset(VAL_SUBS, PSG_EEG_PATH, STUDENT_DATA_PATH)
print("Test:")
test_ds  = KDDataset(TEST_SUBS, PSG_EEG_PATH, STUDENT_DATA_PATH)

for name, ds in [("train", train_ds), ("val", val_ds), ("test", test_ds)]:
    if len(ds) == 0:
        raise RuntimeError(f"{name}_ds has 0 samples! Check PSG_EEG_PATH / STUDENT_DATA_PATH.")
print("Datasets ready.")


# ============================================================
# LOAD FROZEN TEACHER ENSEMBLE
# ============================================================
print(f"\nLoading {len(TEACHER_SEEDS)} frozen teacher checkpoints from {TEACHER_CKPT_DIR}...")
teachers = []
for seed in TEACHER_SEEDS:
    ckpt = os.path.join(TEACHER_CKPT_DIR, f"best_seed{seed}.pt")
    if not os.path.exists(ckpt):
        print(f"  MISSING: {ckpt}")
        continue
    m = MultiScaleSleepNetPlain(in_ch=3).to(device)
    m.load_state_dict(torch.load(ckpt, map_location=device))
    m.eval()
    for p in m.parameters():
        p.requires_grad = False
    teachers.append(m)
print(f"Loaded {len(teachers)} teacher models (frozen).")
if len(teachers) == 0:
    raise RuntimeError(f"No teacher checkpoints found in {TEACHER_CKPT_DIR}.")


@torch.no_grad()
def teacher_soft_targets(psg_x, temperature=KD_TEMPERATURE):
    probs_sum = None
    for m in teachers:
        logits = m(psg_x)
        probs = F.softmax(logits / temperature, dim=1)
        probs_sum = probs if probs_sum is None else probs_sum + probs
    return probs_sum / len(teachers)


# ============================================================
# CLASS WEIGHTS -- from TRAIN only
# ============================================================
all_train_labels = []
for _, _, _, _, _, labs in train_ds.data:
    all_train_labels.extend(labs.tolist())
label_counts = np.array([Counter(all_train_labels).get(i, 1) for i in range(5)], dtype=np.float32)
cw = torch.FloatTensor(label_counts.sum() / (5 * label_counts)).to(device)
print(f"\nClass weights (from TRAIN set only): {dict(zip(LABEL_NAMES, cw.cpu().numpy().round(3)))}")


def set_seed(seed):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


def kd_loss_fn(student_logits, teacher_probs, labels, temperature, lam, class_weights):
    """L = L_CE + lambda_KD * L_KD  (plain CE, no artifact-weighted loss -- that's S4)"""
    student_log_probs = F.log_softmax(student_logits / temperature, dim=1)
    kd = F.kl_div(student_log_probs, teacher_probs, reduction='batchmean') * (temperature ** 2)
    ce = F.cross_entropy(student_logits, labels, weight=class_weights)
    total = ce + lam * kd
    return total, kd.item(), ce.item()


def train_epoch(model, loader, optimizer, scheduler):
    model.train()
    total_loss = total_kd = total_ce = 0
    preds, labs_all = [], []
    for psg_x, zmax_x, e4_x, aw, y in loader:
        psg_x, zmax_x, e4_x, aw, y = (
            psg_x.to(device), zmax_x.to(device), e4_x.to(device),
            aw.to(device), y.to(device)
        )
        optimizer.zero_grad()
        teacher_probs = teacher_soft_targets(psg_x)
        student_logits, gate = model(zmax_x, e4_x, aw)
        loss, kd_val, ce_val = kd_loss_fn(
            student_logits, teacher_probs, y, KD_TEMPERATURE, KD_LAMBDA, cw
        )
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()

        total_loss += loss.item(); total_kd += kd_val; total_ce += ce_val
        preds.extend(student_logits.argmax(1).cpu().numpy())
        labs_all.extend(y.cpu().numpy())

    n = len(loader)
    acc = accuracy_score(labs_all, preds)
    f1 = f1_score(labs_all, preds, average='macro', zero_division=0)
    return total_loss / n, total_kd / n, total_ce / n, acc, f1


@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    preds, labs_all, gates_all, aw_all = [], [], [], []
    for psg_x, zmax_x, e4_x, aw, y in loader:
        zmax_x, e4_x, aw = zmax_x.to(device), e4_x.to(device), aw.to(device)
        logits, gate = model(zmax_x, e4_x, aw)
        preds.extend(logits.argmax(1).cpu().numpy())
        labs_all.extend(y.numpy())
        gates_all.extend(gate.cpu().numpy().flatten())
        aw_all.extend(aw.cpu().numpy())
    preds, labs_all = np.array(preds), np.array(labs_all)
    gates_all, aw_all = np.array(gates_all), np.array(aw_all)

    acc = accuracy_score(labs_all, preds)
    f1 = f1_score(labs_all, preds, average='macro', zero_division=0)
    kappa = cohen_kappa_score(labs_all, preds)
    per_cls = f1_score(labs_all, preds, average=None, zero_division=0, labels=[0, 1, 2, 3, 4])

    clean_mask = aw_all >= 0.9
    noisy_mask = aw_all < 0.5
    gate_clean = gates_all[clean_mask].mean() if clean_mask.sum() > 0 else float('nan')
    gate_noisy = gates_all[noisy_mask].mean() if noisy_mask.sum() > 0 else float('nan')

    return acc, f1, kappa, per_cls, gates_all.mean(), gate_clean, gate_noisy


# ============================================================
# CSV SETUP
# ============================================================
epoch_csv_path = os.path.join(EVAL_PATH, "epoch_log.csv")
epoch_fields = [
    "seed", "epoch", "train_loss", "train_ce", "train_kd", "train_acc", "train_f1_macro",
    "val_acc", "val_f1_macro", "val_kappa",
    "val_f1_Wake", "val_f1_N1", "val_f1_N2", "val_f1_N3", "val_f1_REM",
    "val_mean_gate", "val_gate_clean", "val_gate_noisy",
    "lr", "is_best",
]
with open(epoch_csv_path, 'w', newline='') as f:
    csv.DictWriter(f, epoch_fields).writeheader()

csv_path = os.path.join(EVAL_PATH, "summary.csv")
fields = ["seed", "best_epoch", "best_val_f1", "acc", "f1_macro", "kappa",
          "f1_Wake", "f1_N1", "f1_N2", "f1_N3", "f1_REM",
          "mean_gate", "gate_clean", "gate_noisy"]
with open(csv_path, 'w', newline='') as f:
    csv.DictWriter(f, fields).writeheader()

all_results = []
for seed_idx, seed in enumerate(SEEDS):
    print(f"\n{'='*60}\nSTUDENT SEED {seed}  ({seed_idx+1}/{len(SEEDS)})\n{'='*60}")
    set_seed(seed)

    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                               num_workers=0, generator=torch.Generator().manual_seed(seed))
    val_loader  = DataLoader(val_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
    test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

    model = ArtifactGatedStudentModel().to(device)
    n_params = sum(p.numel() for p in model.parameters())
    print(f"  Student parameters: {n_params:,}  (teacher frozen, not counted)")

    optimizer = optim.AdamW(model.parameters(), lr=5e-4, weight_decay=3e-4, betas=(0.9, 0.98), eps=1e-9)
    total_steps = N_EPOCHS * len(train_loader)
    warmup_steps = int(0.05 * total_steps)

    def warmup_cosine(step):
        if step < warmup_steps:
            return step / max(warmup_steps, 1)
        t = (step - warmup_steps) / max(total_steps - warmup_steps, 1)
        return 0.5 * (1 + math.cos(math.pi * t))

    scheduler = optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=warmup_cosine)

    best_val_f1 = 0.0
    best_epoch  = -1
    best_path = os.path.join(EVAL_PATH, f"best_student_seed{seed}.pt")

    for epoch in range(1, N_EPOCHS + 1):
        tr_loss, tr_kd, tr_ce, tr_acc, tr_f1 = train_epoch(model, train_loader, optimizer, scheduler)
        vl_acc, vl_f1, vl_kap, vl_per, vl_gate, vl_gate_clean, vl_gate_noisy = evaluate(model, val_loader)

        is_best = 0
        if vl_f1 > best_val_f1:
            best_val_f1 = vl_f1
            best_epoch  = epoch
            torch.save(model.state_dict(), best_path)
            is_best = 1

        tag = " <- BEST" if is_best else ""
        print(f"  Ep[{epoch:02d}/{N_EPOCHS}] Loss:{tr_loss:.3f}(CE:{tr_ce:.3f}+KD:{tr_kd:.3f}) "
              f"TrF1:{tr_f1:.3f} | ValAcc:{vl_acc:.3f} ValF1:{vl_f1:.3f} Valk:{vl_kap:.3f} "
              f"gate(mean/clean/noisy):{vl_gate:.2f}/{vl_gate_clean:.2f}/{vl_gate_noisy:.2f}{tag}")

        with open(epoch_csv_path, 'a', newline='') as f:
            csv.DictWriter(f, epoch_fields).writerow({
                "seed": seed, "epoch": epoch,
                "train_loss": round(tr_loss, 6), "train_ce": round(tr_ce, 6), "train_kd": round(tr_kd, 6),
                "train_acc": round(tr_acc, 6), "train_f1_macro": round(tr_f1, 6),
                "val_acc": round(vl_acc, 6), "val_f1_macro": round(vl_f1, 6), "val_kappa": round(vl_kap, 6),
                "val_f1_Wake": round(vl_per[0], 6), "val_f1_N1": round(vl_per[1], 6),
                "val_f1_N2": round(vl_per[2], 6), "val_f1_N3": round(vl_per[3], 6),
                "val_f1_REM": round(vl_per[4], 6),
                "val_mean_gate": round(vl_gate, 4), "val_gate_clean": round(vl_gate_clean, 4),
                "val_gate_noisy": round(vl_gate_noisy, 4),
                "lr": optimizer.param_groups[0]['lr'], "is_best": is_best,
            })

    model.load_state_dict(torch.load(best_path, map_location=device))
    fin_acc, fin_f1, fin_kap, fin_per, fin_gate, fin_gate_clean, fin_gate_noisy = evaluate(model, test_loader)

    print(f"\n  Seed {seed}: best val F1={best_val_f1:.4f} at epoch {best_epoch}")
    print(f"  Seed {seed} FINAL TEST (evaluated once): Acc={fin_acc*100:.2f}% F1={fin_f1:.4f} k={fin_kap:.4f}")
    print(f"  Gate -- mean:{fin_gate:.3f}  on clean epochs:{fin_gate_clean:.3f}  on noisy epochs:{fin_gate_noisy:.3f}")
    for i, name in enumerate(LABEL_NAMES):
        print(f"    {name:6s}: {fin_per[i]:.4f}")

    all_results.append({
        'seed': seed, 'acc': fin_acc, 'f1': fin_f1, 'kappa': fin_kap, 'per_cls': fin_per,
        'gate': fin_gate, 'gate_clean': fin_gate_clean, 'gate_noisy': fin_gate_noisy,
        'best_epoch': best_epoch, 'best_val_f1': best_val_f1
    })
    with open(csv_path, 'a', newline='') as f:
        csv.DictWriter(f, fields).writerow({
            "seed": seed, "best_epoch": best_epoch, "best_val_f1": round(best_val_f1, 4),
            "acc": round(fin_acc, 4), "f1_macro": round(fin_f1, 4), "kappa": round(fin_kap, 4),
            "f1_Wake": round(fin_per[0], 4), "f1_N1": round(fin_per[1], 4),
            "f1_N2": round(fin_per[2], 4), "f1_N3": round(fin_per[3], 4),
            "f1_REM": round(fin_per[4], 4),
            "mean_gate": round(fin_gate, 4),
            "gate_clean": round(fin_gate_clean, 4), "gate_noisy": round(fin_gate_noisy, 4),
        })

# ============================================================
# FINAL REPORT
# ============================================================
accs = np.array([r['acc'] for r in all_results]) * 100
f1s = np.array([r['f1'] for r in all_results])
kappas = np.array([r['kappa'] for r in all_results])
gates_clean = np.array([r['gate_clean'] for r in all_results])
gates_noisy = np.array([r['gate_noisy'] for r in all_results])

print(f"\n{'='*60}\nS3: ARTIFACT-GATED STUDENT + KD (VAL-SELECTED, HONEST TEST) -- 5-SEED REPORT\n{'='*60}")
print(f"Accuracy : {accs.mean():.2f} +- {accs.std():.2f}%")
print(f"Macro F1 : {f1s.mean():.4f} +- {f1s.std():.4f}")
print(f"Kappa    : {kappas.mean():.4f} +- {kappas.std():.4f}")
print(f"Gate on clean epochs : {gates_clean.mean():.3f}")
print(f"Gate on noisy epochs : {gates_noisy.mean():.3f}")

print("\nCompare against your re-run S2 (on this same split) to isolate")
print("the effect of artifact-aware gating alone.")

print(f"\nEpoch log : {epoch_csv_path}")
print(f"Summary   : {csv_path}")
print("Done!")
# Out:
# Device        : cuda
# S3: Artifact-conditioned gated fusion + KD (no artifact loss weighting yet)
# KD lambda     : 0.5   Temperature: 4.0
# Output        : D:\22\AA\AA journal\evaluation\teacher-student\s3_artifact_gated_kd
# Split loaded -> Train:65  Val:11  Test:20
#
# Building KD datasets...
# Train:
#   Subjects loaded: 61  (large mismatches: 0)
#   Samples: 57,021
# Val:
#   Subjects loaded: 10  (large mismatches: 0)
#   Samples: 9,742
# Test:
#   Subjects loaded: 19  (large mismatches: 0)
#   Samples: 18,898
# Datasets ready.
#
# Loading 5 frozen teacher checkpoints from D:\22\AA\AA journal\evaluation\multiscale_plain_c7_valfixed...
# Loaded 5 teacher models (frozen).
#
# Class weights (from TRAIN set only): {'Wake': np.float32(2.094), 'N1': np.float32(3.192), 'N2': np.float32(0.436), 'N3': np.float32(1.0), 'REM': np.float32(1.092)}
#
# ============================================================
# STUDENT SEED 42  (1/5)
# ============================================================
#   Student parameters: 157,014  (teacher frozen, not counted)
#   Ep[01/30] Loss:5.289(CE:1.498+KD:7.582) TrF1:0.389 | ValAcc:0.536 ValF1:0.449 Valk:0.369 gate(mean/clean/noisy):0.49/0.50/0.45 <- BEST
#   Ep[02/30] Loss:4.278(CE:1.397+KD:5.762) TrF1:0.497 | ValAcc:0.585 ValF1:0.489 Valk:0.426 gate(mean/clean/noisy):0.62/0.63/0.58 <- BEST
#   Ep[03/30] Loss:3.868(CE:1.310+KD:5.117) TrF1:0.541 | ValAcc:0.574 ValF1:0.506 Valk:0.428 gate(mean/clean/noisy):0.63/0.64/0.61 <- BEST
#   Ep[04/30] Loss:3.624(CE:1.253+KD:4.743) TrF1:0.568 | ValAcc:0.625 ValF1:0.545 Valk:0.491 gate(mean/clean/noisy):0.64/0.65/0.60 <- BEST
#   Ep[05/30] Loss:3.453(CE:1.204+KD:4.498) TrF1:0.586 | ValAcc:0.621 ValF1:0.557 Valk:0.497 gate(mean/clean/noisy):0.64/0.65/0.61 <- BEST
#   Ep[06/30] Loss:3.305(CE:1.168+KD:4.273) TrF1:0.602 | ValAcc:0.633 ValF1:0.566 Valk:0.510 gate(mean/clean/noisy):0.65/0.66/0.61 <- BEST
#   Ep[07/30] Loss:3.177(CE:1.138+KD:4.078) TrF1:0.619 | ValAcc:0.642 ValF1:0.573 Valk:0.519 gate(mean/clean/noisy):0.65/0.67/0.60 <- BEST
#   Ep[08/30] Loss:3.076(CE:1.110+KD:3.931) TrF1:0.625 | ValAcc:0.633 ValF1:0.572 Valk:0.517 gate(mean/clean/noisy):0.67/0.68/0.63
#   Ep[09/30] Loss:2.980(CE:1.086+KD:3.787) TrF1:0.636 | ValAcc:0.652 ValF1:0.582 Valk:0.530 gate(mean/clean/noisy):0.63/0.64/0.58 <- BEST
#   Ep[10/30] Loss:2.917(CE:1.069+KD:3.695) TrF1:0.645 | ValAcc:0.659 ValF1:0.587 Valk:0.542 gate(mean/clean/noisy):0.70/0.71/0.64 <- BEST
#   Ep[11/30] Loss:2.820(CE:1.036+KD:3.569) TrF1:0.653 | ValAcc:0.645 ValF1:0.580 Valk:0.530 gate(mean/clean/noisy):0.69/0.70/0.65
#   Ep[12/30] Loss:2.754(CE:1.020+KD:3.467) TrF1:0.661 | ValAcc:0.658 ValF1:0.591 Valk:0.544 gate(mean/clean/noisy):0.73/0.74/0.69 <- BEST
#   Ep[13/30] Loss:2.671(CE:0.996+KD:3.351) TrF1:0.669 | ValAcc:0.662 ValF1:0.596 Valk:0.551 gate(mean/clean/noisy):0.68/0.69/0.62 <- BEST
#   Ep[14/30] Loss:2.621(CE:0.977+KD:3.288) TrF1:0.674 | ValAcc:0.658 ValF1:0.596 Valk:0.550 gate(mean/clean/noisy):0.70/0.71/0.65
#   Ep[15/30] Loss:2.578(CE:0.965+KD:3.225) TrF1:0.678 | ValAcc:0.673 ValF1:0.606 Valk:0.564 gate(mean/clean/noisy):0.72/0.73/0.68 <- BEST
#   Ep[16/30] Loss:2.531(CE:0.953+KD:3.156) TrF1:0.683 | ValAcc:0.671 ValF1:0.610 Valk:0.564 gate(mean/clean/noisy):0.68/0.69/0.66 <- BEST
#   Ep[17/30] Loss:2.480(CE:0.937+KD:3.087) TrF1:0.691 | ValAcc:0.676 ValF1:0.605 Valk:0.566 gate(mean/clean/noisy):0.71/0.72/0.67
#   Ep[18/30] Loss:2.456(CE:0.931+KD:3.050) TrF1:0.693 | ValAcc:0.679 ValF1:0.614 Valk:0.574 gate(mean/clean/noisy):0.68/0.69/0.65 <- BEST
#   Ep[19/30] Loss:2.409(CE:0.913+KD:2.991) TrF1:0.694 | ValAcc:0.681 ValF1:0.612 Valk:0.575 gate(mean/clean/noisy):0.71/0.72/0.69
#   Ep[20/30] Loss:2.367(CE:0.898+KD:2.937) TrF1:0.700 | ValAcc:0.684 ValF1:0.612 Valk:0.579 gate(mean/clean/noisy):0.70/0.71/0.67
#   Ep[21/30] Loss:2.329(CE:0.887+KD:2.885) TrF1:0.703 | ValAcc:0.686 ValF1:0.611 Valk:0.579 gate(mean/clean/noisy):0.71/0.72/0.68
#   Ep[22/30] Loss:2.313(CE:0.882+KD:2.862) TrF1:0.707 | ValAcc:0.688 ValF1:0.620 Valk:0.584 gate(mean/clean/noisy):0.70/0.71/0.67 <- BEST
#   Ep[23/30] Loss:2.290(CE:0.874+KD:2.833) TrF1:0.709 | ValAcc:0.679 ValF1:0.612 Valk:0.573 gate(mean/clean/noisy):0.72/0.73/0.69
#   Ep[24/30] Loss:2.266(CE:0.864+KD:2.803) TrF1:0.710 | ValAcc:0.675 ValF1:0.607 Valk:0.566 gate(mean/clean/noisy):0.71/0.72/0.68
#   Ep[25/30] Loss:2.241(CE:0.855+KD:2.772) TrF1:0.711 | ValAcc:0.682 ValF1:0.616 Valk:0.577 gate(mean/clean/noisy):0.70/0.71/0.68
#   Ep[26/30] Loss:2.222(CE:0.846+KD:2.753) TrF1:0.716 | ValAcc:0.677 ValF1:0.607 Valk:0.568 gate(mean/clean/noisy):0.71/0.72/0.68
#   Ep[27/30] Loss:2.211(CE:0.843+KD:2.736) TrF1:0.716 | ValAcc:0.673 ValF1:0.606 Valk:0.566 gate(mean/clean/noisy):0.70/0.71/0.68
#   Ep[28/30] Loss:2.214(CE:0.843+KD:2.743) TrF1:0.715 | ValAcc:0.690 ValF1:0.623 Valk:0.587 gate(mean/clean/noisy):0.70/0.70/0.68 <- BEST
#   Ep[29/30] Loss:2.203(CE:0.843+KD:2.721) TrF1:0.716 | ValAcc:0.680 ValF1:0.612 Valk:0.574 gate(mean/clean/noisy):0.70/0.71/0.68
#   Ep[30/30] Loss:2.202(CE:0.842+KD:2.719) TrF1:0.718 | ValAcc:0.687 ValF1:0.618 Valk:0.582 gate(mean/clean/noisy):0.70/0.71/0.68
#
#   Seed 42: best val F1=0.6227 at epoch 28
#   Seed 42 FINAL TEST (evaluated once): Acc=58.47% F1=0.5034 k=0.4223
#   Gate -- mean:0.670  on clean epochs:0.731  on noisy epochs:0.579
#     Wake  : 0.4681
#     N1    : 0.2311
#     N2    : 0.6876
#     N3    : 0.6006
#     REM   : 0.5295
#
# ============================================================
# STUDENT SEED 123  (2/5)
# ============================================================
#   Student parameters: 157,014  (teacher frozen, not counted)
#   Ep[01/30] Loss:5.333(CE:1.502+KD:7.661) TrF1:0.384 | ValAcc:0.535 ValF1:0.444 Valk:0.370 gate(mean/clean/noisy):0.50/0.51/0.48 <- BEST
#   Ep[02/30] Loss:4.247(CE:1.388+KD:5.720) TrF1:0.499 | ValAcc:0.581 ValF1:0.493 Valk:0.433 gate(mean/clean/noisy):0.55/0.56/0.50 <- BEST
#   Ep[03/30] Loss:3.909(CE:1.321+KD:5.176) TrF1:0.539 | ValAcc:0.584 ValF1:0.513 Valk:0.447 gate(mean/clean/noisy):0.56/0.58/0.52 <- BEST
#   Ep[04/30] Loss:3.682(CE:1.267+KD:4.829) TrF1:0.561 | ValAcc:0.595 ValF1:0.527 Valk:0.458 gate(mean/clean/noisy):0.61/0.62/0.55 <- BEST
#   Ep[05/30] Loss:3.510(CE:1.225+KD:4.571) TrF1:0.581 | ValAcc:0.621 ValF1:0.553 Valk:0.487 gate(mean/clean/noisy):0.58/0.59/0.55 <- BEST
#   Ep[06/30] Loss:3.350(CE:1.179+KD:4.342) TrF1:0.598 | ValAcc:0.609 ValF1:0.552 Valk:0.487 gate(mean/clean/noisy):0.61/0.62/0.55
#   Ep[07/30] Loss:3.232(CE:1.150+KD:4.164) TrF1:0.611 | ValAcc:0.642 ValF1:0.568 Valk:0.520 gate(mean/clean/noisy):0.61/0.62/0.57 <- BEST
#   Ep[08/30] Loss:3.139(CE:1.128+KD:4.023) TrF1:0.624 | ValAcc:0.636 ValF1:0.570 Valk:0.510 gate(mean/clean/noisy):0.65/0.66/0.61 <- BEST
#   Ep[09/30] Loss:3.033(CE:1.099+KD:3.867) TrF1:0.630 | ValAcc:0.641 ValF1:0.575 Valk:0.522 gate(mean/clean/noisy):0.63/0.64/0.58 <- BEST
#   Ep[10/30] Loss:2.953(CE:1.076+KD:3.754) TrF1:0.640 | ValAcc:0.654 ValF1:0.584 Valk:0.535 gate(mean/clean/noisy):0.65/0.67/0.59 <- BEST
#   Ep[11/30] Loss:2.877(CE:1.054+KD:3.647) TrF1:0.649 | ValAcc:0.673 ValF1:0.600 Valk:0.563 gate(mean/clean/noisy):0.65/0.66/0.63 <- BEST
#   Ep[12/30] Loss:2.788(CE:1.029+KD:3.517) TrF1:0.659 | ValAcc:0.651 ValF1:0.575 Valk:0.533 gate(mean/clean/noisy):0.66/0.67/0.61
#   Ep[13/30] Loss:2.740(CE:1.011+KD:3.459) TrF1:0.663 | ValAcc:0.666 ValF1:0.595 Valk:0.554 gate(mean/clean/noisy):0.65/0.67/0.60
#   Ep[14/30] Loss:2.677(CE:0.995+KD:3.365) TrF1:0.670 | ValAcc:0.654 ValF1:0.587 Valk:0.541 gate(mean/clean/noisy):0.66/0.67/0.60
#   Ep[15/30] Loss:2.604(CE:0.974+KD:3.261) TrF1:0.676 | ValAcc:0.651 ValF1:0.582 Valk:0.537 gate(mean/clean/noisy):0.68/0.69/0.62
#   Ep[16/30] Loss:2.567(CE:0.966+KD:3.201) TrF1:0.680 | ValAcc:0.640 ValF1:0.573 Valk:0.521 gate(mean/clean/noisy):0.66/0.68/0.61
#   Ep[17/30] Loss:2.526(CE:0.950+KD:3.152) TrF1:0.688 | ValAcc:0.676 ValF1:0.607 Valk:0.568 gate(mean/clean/noisy):0.67/0.69/0.61 <- BEST
#   Ep[18/30] Loss:2.466(CE:0.930+KD:3.072) TrF1:0.692 | ValAcc:0.687 ValF1:0.613 Valk:0.581 gate(mean/clean/noisy):0.68/0.69/0.63 <- BEST
#   Ep[19/30] Loss:2.437(CE:0.926+KD:3.022) TrF1:0.694 | ValAcc:0.679 ValF1:0.605 Valk:0.569 gate(mean/clean/noisy):0.66/0.67/0.62
#   Ep[20/30] Loss:2.397(CE:0.909+KD:2.976) TrF1:0.699 | ValAcc:0.677 ValF1:0.604 Valk:0.566 gate(mean/clean/noisy):0.67/0.68/0.63
#   Ep[21/30] Loss:2.373(CE:0.906+KD:2.935) TrF1:0.699 | ValAcc:0.679 ValF1:0.610 Valk:0.570 gate(mean/clean/noisy):0.66/0.67/0.62
#   Ep[22/30] Loss:2.337(CE:0.891+KD:2.891) TrF1:0.703 | ValAcc:0.682 ValF1:0.614 Valk:0.575 gate(mean/clean/noisy):0.66/0.68/0.62 <- BEST
#   Ep[23/30] Loss:2.317(CE:0.881+KD:2.870) TrF1:0.705 | ValAcc:0.660 ValF1:0.594 Valk:0.549 gate(mean/clean/noisy):0.67/0.68/0.62
#   Ep[24/30] Loss:2.289(CE:0.875+KD:2.828) TrF1:0.708 | ValAcc:0.649 ValF1:0.584 Valk:0.536 gate(mean/clean/noisy):0.67/0.68/0.62
#   Ep[25/30] Loss:2.272(CE:0.867+KD:2.810) TrF1:0.709 | ValAcc:0.677 ValF1:0.604 Valk:0.567 gate(mean/clean/noisy):0.67/0.68/0.62
#   Ep[26/30] Loss:2.251(CE:0.861+KD:2.781) TrF1:0.713 | ValAcc:0.667 ValF1:0.596 Valk:0.555 gate(mean/clean/noisy):0.67/0.68/0.63
#   Ep[27/30] Loss:2.237(CE:0.859+KD:2.755) TrF1:0.714 | ValAcc:0.673 ValF1:0.604 Valk:0.564 gate(mean/clean/noisy):0.67/0.68/0.63
#   Ep[28/30] Loss:2.230(CE:0.854+KD:2.753) TrF1:0.715 | ValAcc:0.661 ValF1:0.593 Valk:0.549 gate(mean/clean/noisy):0.67/0.68/0.63
#   Ep[29/30] Loss:2.239(CE:0.854+KD:2.770) TrF1:0.712 | ValAcc:0.684 ValF1:0.613 Valk:0.577 gate(mean/clean/noisy):0.66/0.67/0.62
#   Ep[30/30] Loss:2.222(CE:0.849+KD:2.747) TrF1:0.715 | ValAcc:0.643 ValF1:0.576 Valk:0.527 gate(mean/clean/noisy):0.67/0.68/0.62
#
#   Seed 123: best val F1=0.6137 at epoch 22
#   Seed 123 FINAL TEST (evaluated once): Acc=60.09% F1=0.5178 k=0.4277
#   Gate -- mean:0.643  on clean epochs:0.716  on noisy epochs:0.534
#     Wake  : 0.5068
#     N1    : 0.2598
#     N2    : 0.7039
#     N3    : 0.5840
#     REM   : 0.5345
#
# ============================================================
# STUDENT SEED 256  (3/5)
# ============================================================
#   Student parameters: 157,014  (teacher frozen, not counted)
#   Ep[01/30] Loss:5.267(CE:1.524+KD:7.486) TrF1:0.387 | ValAcc:0.544 ValF1:0.452 Valk:0.384 gate(mean/clean/noisy):0.50/0.51/0.46 <- BEST
#   Ep[02/30] Loss:4.329(CE:1.417+KD:5.824) TrF1:0.494 | ValAcc:0.576 ValF1:0.499 Valk:0.430 gate(mean/clean/noisy):0.55/0.56/0.51 <- BEST
#   Ep[03/30] Loss:3.942(CE:1.327+KD:5.231) TrF1:0.535 | ValAcc:0.612 ValF1:0.528 Valk:0.477 gate(mean/clean/noisy):0.57/0.58/0.51 <- BEST
#   Ep[04/30] Loss:3.693(CE:1.271+KD:4.845) TrF1:0.560 | ValAcc:0.625 ValF1:0.543 Valk:0.495 gate(mean/clean/noisy):0.62/0.63/0.57 <- BEST
#   Ep[05/30] Loss:3.498(CE:1.220+KD:4.556) TrF1:0.586 | ValAcc:0.625 ValF1:0.550 Valk:0.490 gate(mean/clean/noisy):0.61/0.63/0.56 <- BEST
#   Ep[06/30] Loss:3.331(CE:1.175+KD:4.313) TrF1:0.597 | ValAcc:0.623 ValF1:0.552 Valk:0.493 gate(mean/clean/noisy):0.59/0.61/0.55 <- BEST
#   Ep[07/30] Loss:3.188(CE:1.136+KD:4.104) TrF1:0.616 | ValAcc:0.645 ValF1:0.574 Valk:0.524 gate(mean/clean/noisy):0.63/0.64/0.56 <- BEST
#   Ep[08/30] Loss:3.090(CE:1.116+KD:3.946) TrF1:0.625 | ValAcc:0.631 ValF1:0.564 Valk:0.507 gate(mean/clean/noisy):0.64/0.66/0.57
#   Ep[09/30] Loss:2.996(CE:1.086+KD:3.820) TrF1:0.639 | ValAcc:0.635 ValF1:0.573 Valk:0.515 gate(mean/clean/noisy):0.64/0.65/0.58
#   Ep[10/30] Loss:2.901(CE:1.059+KD:3.684) TrF1:0.648 | ValAcc:0.663 ValF1:0.595 Valk:0.545 gate(mean/clean/noisy):0.67/0.69/0.59 <- BEST
#   Ep[11/30] Loss:2.809(CE:1.034+KD:3.551) TrF1:0.656 | ValAcc:0.659 ValF1:0.585 Valk:0.542 gate(mean/clean/noisy):0.67/0.69/0.61
#   Ep[12/30] Loss:2.750(CE:1.017+KD:3.466) TrF1:0.662 | ValAcc:0.658 ValF1:0.593 Valk:0.545 gate(mean/clean/noisy):0.66/0.68/0.59
#   Ep[13/30] Loss:2.698(CE:1.005+KD:3.385) TrF1:0.668 | ValAcc:0.659 ValF1:0.589 Valk:0.543 gate(mean/clean/noisy):0.68/0.70/0.62
#   Ep[14/30] Loss:2.641(CE:0.987+KD:3.308) TrF1:0.673 | ValAcc:0.645 ValF1:0.579 Valk:0.526 gate(mean/clean/noisy):0.68/0.70/0.63
#   Ep[15/30] Loss:2.593(CE:0.972+KD:3.243) TrF1:0.678 | ValAcc:0.670 ValF1:0.602 Valk:0.558 gate(mean/clean/noisy):0.69/0.70/0.64 <- BEST
#   Ep[16/30] Loss:2.553(CE:0.966+KD:3.173) TrF1:0.685 | ValAcc:0.659 ValF1:0.593 Valk:0.547 gate(mean/clean/noisy):0.68/0.70/0.61
#   Ep[17/30] Loss:2.514(CE:0.948+KD:3.132) TrF1:0.685 | ValAcc:0.672 ValF1:0.606 Valk:0.562 gate(mean/clean/noisy):0.67/0.69/0.60 <- BEST
#   Ep[18/30] Loss:2.469(CE:0.937+KD:3.064) TrF1:0.692 | ValAcc:0.674 ValF1:0.607 Valk:0.565 gate(mean/clean/noisy):0.69/0.71/0.62 <- BEST
#   Ep[19/30] Loss:2.431(CE:0.926+KD:3.011) TrF1:0.697 | ValAcc:0.662 ValF1:0.597 Valk:0.552 gate(mean/clean/noisy):0.69/0.71/0.63
#   Ep[20/30] Loss:2.406(CE:0.914+KD:2.983) TrF1:0.699 | ValAcc:0.673 ValF1:0.604 Valk:0.562 gate(mean/clean/noisy):0.70/0.72/0.63
#   Ep[21/30] Loss:2.367(CE:0.908+KD:2.919) TrF1:0.703 | ValAcc:0.668 ValF1:0.603 Valk:0.560 gate(mean/clean/noisy):0.69/0.70/0.63
#   Ep[22/30] Loss:2.341(CE:0.896+KD:2.890) TrF1:0.705 | ValAcc:0.670 ValF1:0.604 Valk:0.562 gate(mean/clean/noisy):0.71/0.72/0.64
#   Ep[23/30] Loss:2.313(CE:0.885+KD:2.856) TrF1:0.711 | ValAcc:0.660 ValF1:0.593 Valk:0.547 gate(mean/clean/noisy):0.68/0.70/0.61
#   Ep[24/30] Loss:2.297(CE:0.881+KD:2.831) TrF1:0.711 | ValAcc:0.665 ValF1:0.597 Valk:0.553 gate(mean/clean/noisy):0.69/0.70/0.63
#   Ep[25/30] Loss:2.286(CE:0.876+KD:2.819) TrF1:0.712 | ValAcc:0.665 ValF1:0.598 Valk:0.554 gate(mean/clean/noisy):0.68/0.70/0.62
#   Ep[26/30] Loss:2.267(CE:0.871+KD:2.792) TrF1:0.712 | ValAcc:0.665 ValF1:0.593 Valk:0.549 gate(mean/clean/noisy):0.68/0.70/0.62
#   Ep[27/30] Loss:2.248(CE:0.864+KD:2.768) TrF1:0.714 | ValAcc:0.659 ValF1:0.595 Valk:0.548 gate(mean/clean/noisy):0.68/0.70/0.62
#   Ep[28/30] Loss:2.241(CE:0.862+KD:2.757) TrF1:0.715 | ValAcc:0.665 ValF1:0.599 Valk:0.554 gate(mean/clean/noisy):0.68/0.70/0.63
#   Ep[29/30] Loss:2.253(CE:0.864+KD:2.778) TrF1:0.714 | ValAcc:0.667 ValF1:0.602 Valk:0.557 gate(mean/clean/noisy):0.68/0.70/0.62
#   Ep[30/30] Loss:2.241(CE:0.860+KD:2.761) TrF1:0.717 | ValAcc:0.667 ValF1:0.600 Valk:0.556 gate(mean/clean/noisy):0.69/0.70/0.63
#
#   Seed 256: best val F1=0.6066 at epoch 18
#   Seed 256 FINAL TEST (evaluated once): Acc=58.61% F1=0.5037 k=0.4155
#   Gate -- mean:0.664  on clean epochs:0.752  on noisy epochs:0.533
#     Wake  : 0.4717
#     N1    : 0.2495
#     N2    : 0.6828
#     N3    : 0.5764
#     REM   : 0.5379
#
# ============================================================
# STUDENT SEED 789  (4/5)
# ============================================================
#   Student parameters: 157,014  (teacher frozen, not counted)
#   Ep[01/30] Loss:5.327(CE:1.509+KD:7.637) TrF1:0.376 | ValAcc:0.541 ValF1:0.454 Valk:0.376 gate(mean/clean/noisy):0.46/0.47/0.43 <- BEST
#   Ep[02/30] Loss:4.289(CE:1.400+KD:5.779) TrF1:0.495 | ValAcc:0.587 ValF1:0.497 Valk:0.436 gate(mean/clean/noisy):0.53/0.55/0.46 <- BEST
#   Ep[03/30] Loss:3.874(CE:1.309+KD:5.128) TrF1:0.536 | ValAcc:0.614 ValF1:0.523 Valk:0.478 gate(mean/clean/noisy):0.55/0.56/0.49 <- BEST
#   Ep[04/30] Loss:3.621(CE:1.249+KD:4.744) TrF1:0.564 | ValAcc:0.590 ValF1:0.522 Valk:0.458 gate(mean/clean/noisy):0.56/0.58/0.50
#   Ep[05/30] Loss:3.414(CE:1.191+KD:4.445) TrF1:0.592 | ValAcc:0.628 ValF1:0.562 Valk:0.505 gate(mean/clean/noisy):0.57/0.59/0.49 <- BEST
#   Ep[06/30] Loss:3.260(CE:1.151+KD:4.217) TrF1:0.607 | ValAcc:0.631 ValF1:0.566 Valk:0.506 gate(mean/clean/noisy):0.65/0.67/0.59 <- BEST
#   Ep[07/30] Loss:3.136(CE:1.116+KD:4.040) TrF1:0.619 | ValAcc:0.652 ValF1:0.587 Valk:0.534 gate(mean/clean/noisy):0.65/0.67/0.59 <- BEST
#   Ep[08/30] Loss:3.025(CE:1.093+KD:3.863) TrF1:0.631 | ValAcc:0.650 ValF1:0.590 Valk:0.537 gate(mean/clean/noisy):0.62/0.63/0.57 <- BEST
#   Ep[09/30] Loss:2.945(CE:1.066+KD:3.759) TrF1:0.638 | ValAcc:0.642 ValF1:0.580 Valk:0.527 gate(mean/clean/noisy):0.63/0.64/0.58
#   Ep[10/30] Loss:2.869(CE:1.049+KD:3.639) TrF1:0.647 | ValAcc:0.652 ValF1:0.583 Valk:0.536 gate(mean/clean/noisy):0.69/0.70/0.62
#   Ep[11/30] Loss:2.770(CE:1.020+KD:3.499) TrF1:0.658 | ValAcc:0.652 ValF1:0.584 Valk:0.537 gate(mean/clean/noisy):0.66/0.68/0.59
#   Ep[12/30] Loss:2.731(CE:1.013+KD:3.437) TrF1:0.662 | ValAcc:0.670 ValF1:0.600 Valk:0.559 gate(mean/clean/noisy):0.67/0.68/0.61 <- BEST
#   Ep[13/30] Loss:2.674(CE:0.995+KD:3.358) TrF1:0.670 | ValAcc:0.651 ValF1:0.581 Valk:0.533 gate(mean/clean/noisy):0.70/0.72/0.65
#   Ep[14/30] Loss:2.599(CE:0.973+KD:3.252) TrF1:0.677 | ValAcc:0.665 ValF1:0.597 Valk:0.553 gate(mean/clean/noisy):0.68/0.69/0.63
#   Ep[15/30] Loss:2.566(CE:0.964+KD:3.205) TrF1:0.681 | ValAcc:0.643 ValF1:0.579 Valk:0.529 gate(mean/clean/noisy):0.66/0.67/0.62
#   Ep[16/30] Loss:2.517(CE:0.948+KD:3.137) TrF1:0.687 | ValAcc:0.640 ValF1:0.570 Valk:0.518 gate(mean/clean/noisy):0.71/0.72/0.66
#   Ep[17/30] Loss:2.464(CE:0.929+KD:3.069) TrF1:0.691 | ValAcc:0.670 ValF1:0.601 Valk:0.558 gate(mean/clean/noisy):0.69/0.70/0.65 <- BEST
#   Ep[18/30] Loss:2.438(CE:0.924+KD:3.026) TrF1:0.694 | ValAcc:0.661 ValF1:0.590 Valk:0.546 gate(mean/clean/noisy):0.69/0.71/0.65
#   Ep[19/30] Loss:2.394(CE:0.909+KD:2.969) TrF1:0.696 | ValAcc:0.650 ValF1:0.584 Valk:0.534 gate(mean/clean/noisy):0.68/0.69/0.63
#   Ep[20/30] Loss:2.349(CE:0.896+KD:2.906) TrF1:0.701 | ValAcc:0.651 ValF1:0.585 Valk:0.537 gate(mean/clean/noisy):0.69/0.71/0.64
#   Ep[21/30] Loss:2.333(CE:0.888+KD:2.890) TrF1:0.703 | ValAcc:0.652 ValF1:0.584 Valk:0.536 gate(mean/clean/noisy):0.69/0.70/0.63
#   Ep[22/30] Loss:2.317(CE:0.886+KD:2.862) TrF1:0.707 | ValAcc:0.654 ValF1:0.583 Valk:0.536 gate(mean/clean/noisy):0.67/0.69/0.62
#   Ep[23/30] Loss:2.290(CE:0.875+KD:2.829) TrF1:0.707 | ValAcc:0.637 ValF1:0.566 Valk:0.514 gate(mean/clean/noisy):0.68/0.70/0.63
#   Ep[24/30] Loss:2.253(CE:0.861+KD:2.786) TrF1:0.712 | ValAcc:0.653 ValF1:0.583 Valk:0.536 gate(mean/clean/noisy):0.68/0.70/0.64
#   Ep[25/30] Loss:2.242(CE:0.861+KD:2.762) TrF1:0.713 | ValAcc:0.655 ValF1:0.584 Valk:0.538 gate(mean/clean/noisy):0.69/0.70/0.64
#   Ep[26/30] Loss:2.235(CE:0.858+KD:2.754) TrF1:0.715 | ValAcc:0.617 ValF1:0.548 Valk:0.488 gate(mean/clean/noisy):0.68/0.70/0.64
#   Ep[27/30] Loss:2.218(CE:0.854+KD:2.728) TrF1:0.716 | ValAcc:0.639 ValF1:0.571 Valk:0.519 gate(mean/clean/noisy):0.68/0.69/0.63
#   Ep[28/30] Loss:2.211(CE:0.848+KD:2.725) TrF1:0.718 | ValAcc:0.655 ValF1:0.585 Valk:0.539 gate(mean/clean/noisy):0.68/0.69/0.63
#   Ep[29/30] Loss:2.209(CE:0.849+KD:2.721) TrF1:0.717 | ValAcc:0.658 ValF1:0.587 Valk:0.541 gate(mean/clean/noisy):0.68/0.70/0.64
#   Ep[30/30] Loss:2.202(CE:0.843+KD:2.716) TrF1:0.717 | ValAcc:0.630 ValF1:0.564 Valk:0.506 gate(mean/clean/noisy):0.69/0.70/0.64
#
#   Seed 789: best val F1=0.6008 at epoch 17
#   Seed 789 FINAL TEST (evaluated once): Acc=59.61% F1=0.5086 k=0.4110
#   Gate -- mean:0.670  on clean epochs:0.743  on noisy epochs:0.561
#     Wake  : 0.5168
#     N1    : 0.2530
#     N2    : 0.6980
#     N3    : 0.5599
#     REM   : 0.5154
#
# ============================================================
# STUDENT SEED 999  (5/5)
# ============================================================
#   Student parameters: 157,014  (teacher frozen, not counted)
#   Ep[01/30] Loss:5.220(CE:1.505+KD:7.431) TrF1:0.390 | ValAcc:0.560 ValF1:0.463 Valk:0.398 gate(mean/clean/noisy):0.50/0.51/0.48 <- BEST
#   Ep[02/30] Loss:4.307(CE:1.405+KD:5.805) TrF1:0.494 | ValAcc:0.575 ValF1:0.498 Valk:0.437 gate(mean/clean/noisy):0.55/0.56/0.53 <- BEST
#   Ep[03/30] Loss:3.943(CE:1.323+KD:5.240) TrF1:0.535 | ValAcc:0.608 ValF1:0.528 Valk:0.475 gate(mean/clean/noisy):0.57/0.58/0.52 <- BEST
#   Ep[04/30] Loss:3.712(CE:1.276+KD:4.871) TrF1:0.561 | ValAcc:0.608 ValF1:0.528 Valk:0.463 gate(mean/clean/noisy):0.58/0.59/0.54
#   Ep[05/30] Loss:3.493(CE:1.211+KD:4.565) TrF1:0.585 | ValAcc:0.621 ValF1:0.562 Valk:0.494 gate(mean/clean/noisy):0.63/0.64/0.57 <- BEST
#   Ep[06/30] Loss:3.325(CE:1.171+KD:4.307) TrF1:0.602 | ValAcc:0.649 ValF1:0.578 Valk:0.533 gate(mean/clean/noisy):0.67/0.68/0.60 <- BEST
#   Ep[07/30] Loss:3.178(CE:1.135+KD:4.086) TrF1:0.616 | ValAcc:0.622 ValF1:0.559 Valk:0.498 gate(mean/clean/noisy):0.65/0.66/0.59
#   Ep[08/30] Loss:3.051(CE:1.103+KD:3.896) TrF1:0.627 | ValAcc:0.639 ValF1:0.579 Valk:0.522 gate(mean/clean/noisy):0.65/0.67/0.60 <- BEST
#   Ep[09/30] Loss:2.963(CE:1.077+KD:3.773) TrF1:0.640 | ValAcc:0.657 ValF1:0.593 Valk:0.543 gate(mean/clean/noisy):0.69/0.71/0.62 <- BEST
#   Ep[10/30] Loss:2.884(CE:1.057+KD:3.653) TrF1:0.646 | ValAcc:0.654 ValF1:0.587 Valk:0.536 gate(mean/clean/noisy):0.66/0.68/0.58
#   Ep[11/30] Loss:2.793(CE:1.030+KD:3.528) TrF1:0.659 | ValAcc:0.634 ValF1:0.578 Valk:0.522 gate(mean/clean/noisy):0.70/0.71/0.64
#   Ep[12/30] Loss:2.729(CE:1.013+KD:3.432) TrF1:0.661 | ValAcc:0.673 ValF1:0.606 Valk:0.565 gate(mean/clean/noisy):0.70/0.72/0.63 <- BEST
#   Ep[13/30] Loss:2.668(CE:0.993+KD:3.351) TrF1:0.672 | ValAcc:0.682 ValF1:0.614 Valk:0.575 gate(mean/clean/noisy):0.70/0.72/0.65 <- BEST
#   Ep[14/30] Loss:2.629(CE:0.978+KD:3.302) TrF1:0.672 | ValAcc:0.682 ValF1:0.615 Valk:0.576 gate(mean/clean/noisy):0.69/0.70/0.64 <- BEST
#   Ep[15/30] Loss:2.568(CE:0.959+KD:3.217) TrF1:0.681 | ValAcc:0.668 ValF1:0.593 Valk:0.557 gate(mean/clean/noisy):0.69/0.70/0.63
#   Ep[16/30] Loss:2.523(CE:0.944+KD:3.157) TrF1:0.685 | ValAcc:0.673 ValF1:0.610 Valk:0.564 gate(mean/clean/noisy):0.69/0.70/0.64
#   Ep[17/30] Loss:2.474(CE:0.932+KD:3.084) TrF1:0.689 | ValAcc:0.663 ValF1:0.597 Valk:0.552 gate(mean/clean/noisy):0.69/0.70/0.64
#   Ep[18/30] Loss:2.427(CE:0.918+KD:3.020) TrF1:0.694 | ValAcc:0.669 ValF1:0.599 Valk:0.559 gate(mean/clean/noisy):0.69/0.70/0.64
#   Ep[19/30] Loss:2.397(CE:0.905+KD:2.984) TrF1:0.697 | ValAcc:0.686 ValF1:0.614 Valk:0.580 gate(mean/clean/noisy):0.71/0.72/0.66
#   Ep[20/30] Loss:2.368(CE:0.895+KD:2.947) TrF1:0.701 | ValAcc:0.679 ValF1:0.609 Valk:0.571 gate(mean/clean/noisy):0.68/0.70/0.64
#   Ep[21/30] Loss:2.333(CE:0.888+KD:2.890) TrF1:0.705 | ValAcc:0.679 ValF1:0.610 Valk:0.571 gate(mean/clean/noisy):0.69/0.70/0.64
#   Ep[22/30] Loss:2.308(CE:0.880+KD:2.856) TrF1:0.708 | ValAcc:0.676 ValF1:0.607 Valk:0.567 gate(mean/clean/noisy):0.67/0.68/0.63
#   Ep[23/30] Loss:2.285(CE:0.871+KD:2.827) TrF1:0.712 | ValAcc:0.675 ValF1:0.607 Valk:0.567 gate(mean/clean/noisy):0.68/0.69/0.63
#   Ep[24/30] Loss:2.264(CE:0.862+KD:2.804) TrF1:0.712 | ValAcc:0.680 ValF1:0.613 Valk:0.572 gate(mean/clean/noisy):0.68/0.69/0.63
#   Ep[25/30] Loss:2.252(CE:0.859+KD:2.785) TrF1:0.712 | ValAcc:0.672 ValF1:0.605 Valk:0.562 gate(mean/clean/noisy):0.68/0.69/0.64
#   Ep[26/30] Loss:2.227(CE:0.845+KD:2.764) TrF1:0.715 | ValAcc:0.690 ValF1:0.620 Valk:0.585 gate(mean/clean/noisy):0.68/0.70/0.64 <- BEST
#   Ep[27/30] Loss:2.230(CE:0.851+KD:2.757) TrF1:0.716 | ValAcc:0.668 ValF1:0.603 Valk:0.559 gate(mean/clean/noisy):0.68/0.69/0.63
#   Ep[28/30] Loss:2.227(CE:0.853+KD:2.749) TrF1:0.714 | ValAcc:0.678 ValF1:0.609 Valk:0.571 gate(mean/clean/noisy):0.69/0.70/0.64
#   Ep[29/30] Loss:2.200(CE:0.836+KD:2.726) TrF1:0.716 | ValAcc:0.684 ValF1:0.617 Valk:0.578 gate(mean/clean/noisy):0.68/0.69/0.64
#   Ep[30/30] Loss:2.202(CE:0.842+KD:2.721) TrF1:0.720 | ValAcc:0.683 ValF1:0.613 Valk:0.576 gate(mean/clean/noisy):0.68/0.69/0.63
#
#   Seed 999: best val F1=0.6203 at epoch 26
#   Seed 999 FINAL TEST (evaluated once): Acc=60.45% F1=0.5174 k=0.4361
#   Gate -- mean:0.659  on clean epochs:0.721  on noisy epochs:0.566
#     Wake  : 0.5000
#     N1    : 0.2465
#     N2    : 0.7097
#     N3    : 0.5755
#     REM   : 0.5555
#
# ============================================================
# S3: ARTIFACT-GATED STUDENT + KD (VAL-SELECTED, HONEST TEST) -- 5-SEED REPORT
# ============================================================
# Accuracy : 59.45 +- 0.78%
# Macro F1 : 0.5102 +- 0.0064
# Kappa    : 0.4225 +- 0.0088
# Gate on clean epochs : 0.733
# Gate on noisy epochs : 0.555
#
# Compare against your re-run S2 (on this same split) to isolate
# the effect of artifact-aware gating alone.
#
# Epoch log : D:\22\AA\AA journal\evaluation\teacher-student\s3_artifact_gated_kd\epoch_log.csv
# Summary   : D:\22\AA\AA journal\evaluation\teacher-student\s3_artifact_gated_kd\summary.csv
# Done!
