# %%
# ============================================================
# S6b: ARTIFACT-AWARE ADAPTIVE KD
#
# Builds on S5 (context-window student, best result so far:
# Acc=65.98%, F1=0.5974, N1=0.3514). This is DIFFERENT from S4's
# artifact-weighted CE:
#
#   S4: scaled the CE (hard-label) term by artifact_weight --
#   noisy epoch -> LESS CE contribution, clean epoch -> full CE.
#   The KD term was left unweighted (constant lambda for everyone).
#
#   S6b (this): the CE weighting logic is UNCHANGED (kept
#   identical to S4/S5). What's NEW is the KD term's weight
#   (lambda) is no longer constant -- it ADAPTS per-sample based
#   on artifact_weight:
#
#       per_sample_kd_lambda = KD_LAMBDA_BASE * (1 + ADAPTIVE_ALPHA * (1 - artifact_weight))
#
#   Rationale: on a noisy Zmax epoch, the RAW STUDENT INPUT is
#   degraded (that's why we reduce its CE weight in S4/S5). But
#   the TEACHER's soft label for that SAME epoch is still fully
#   trustworthy -- the teacher was trained on clean PSG, which is
#   a completely different, artifact-free signal path. So on
#   epochs where the student's own input is unreliable, we lean
#   MORE on the teacher's distilled knowledge (increase KD
#   reliance) rather than less. This is the opposite direction
#   from the CE weighting, and complements it:
#     clean epoch (aw=1.0): CE full weight, KD at base lambda
#     noisy epoch (aw=0.2): CE reduced weight, KD lambda BOOSTED
#
# Uses the 3-way split, VAL-selected checkpoints, TEST evaluated
# once -- same honest protocol as S1-S5.
# ============================================================

import os
import csv
import math
import random
import warnings
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from collections import Counter
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score
warnings.filterwarnings('ignore')

# ============================================================
# PATHS
# ============================================================
PSG_EEG_PATH      = r"D:\22\AA\preprocess\preprocessed_FFinal"
STUDENT_DATA_PATH = r"D:\22\AA\preprocess\preprocessed_student_zmax_e4"
SPLIT_PATH        = r"D:\22\AA\AA journal\preprocess\preprocessed_split_v2"
TEACHER_CKPT_DIR  = r"D:\22\AA\AA journal\evaluation\multiscale_plain_c7_valfixed"

# ============================================================
# MECHANISM-SPECIFIC HYPERPARAMETER
# ============================================================
ADAPTIVE_ALPHA = 1.0     # how strongly noisy epochs boost KD reliance
                          # alpha=0.0 reduces exactly to S5 (sanity check)
                          # alpha=1.0: fully-noisy epoch (aw=0) doubles KD lambda
                          # alpha=2.0: fully-noisy epoch (aw=0) triples KD lambda

# ============================================================
# CONTEXT CONFIG -- same as your best S5 run
# ============================================================
LABEL_NAMES = ["Wake", "N1", "N2", "N3", "REM"]

TEACHER_CONTEXT = 7
TEACHER_WINDOW  = 2 * TEACHER_CONTEXT + 1   # 15, fixed -- matches trained teacher

STUDENT_CONTEXT = 5     # matches your best S5 result
STUDENT_WINDOW  = 2 * STUDENT_CONTEXT + 1

EVAL_PATH = rf"D:\22\AA\AA journal\evaluation\teacher-student\s6b_artifact_adaptive_kd_studentC{STUDENT_CONTEXT}"
os.makedirs(EVAL_PATH, exist_ok=True)

N_EPOCHS    = 30
BATCH_SIZE  = 32
SEEDS         = [42, 123, 256, 789, 999]
TEACHER_SEEDS = [42, 123, 256, 789, 999]

T_D_MODEL = 128
T_DROPOUT = 0.4
T_N_HEADS = 4

S_D_MODEL = 96
S_DROPOUT = 0.3

KD_LAMBDA_BASE = 0.5     # best value found in the S2/S4/S5 sweep
KD_TEMPERATURE = 4.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device        : {device}")
print(f"S6b: ARTIFACT-AWARE ADAPTIVE KD (dynamic per-sample KD weighting)")
print(f"Student context: +-{STUDENT_CONTEXT} (window={STUDENT_WINDOW})")
print(f"KD lambda base: {KD_LAMBDA_BASE}   Temperature: {KD_TEMPERATURE}   Adaptive alpha: {ADAPTIVE_ALPHA}")
print(f"Output        : {EVAL_PATH}")


# ============================================================
# ============  TEACHER ARCHITECTURE (frozen)  ================
# ============================================================
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=8):
        super().__init__()
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Sequential(
            nn.Linear(channels, channels // reduction), nn.ReLU(),
            nn.Linear(channels // reduction, channels), nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _ = x.shape
        s = self.pool(x).view(b, c)
        s = self.fc(s).view(b, c, 1)
        return x * s


class MultiScaleCNN(nn.Module):
    def __init__(self, in_ch=3, d_model=T_D_MODEL, dropout=T_DROPOUT):
        super().__init__()
        mid = d_model // 4

        def time_branch(kernel):
            return nn.Sequential(
                nn.Conv1d(in_ch, mid, kernel_size=kernel, stride=6, padding=kernel // 2),
                nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(4, 4),
                nn.Conv1d(mid, mid, kernel_size=8, padding=4),
                nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(2, 2),
                nn.Dropout(dropout),
            )

        self.small  = time_branch(25)
        self.medium = time_branch(50)
        self.large  = time_branch(100)

        self.spectral = nn.Sequential(
            nn.Conv1d(in_ch, mid, kernel_size=25, stride=6, padding=12),
            nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(4, 4),
            nn.Conv1d(mid, mid, kernel_size=8, padding=4),
            nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(2, 2),
            nn.Dropout(dropout),
        )

        with torch.no_grad():
            dummy = torch.zeros(1, in_ch, 3000)
            L_s = self.small(dummy).shape[2]
            L_m = self.medium(dummy).shape[2]
            L_l = self.large(dummy).shape[2]
            L_f = self.spectral(dummy).shape[2]

        target_L = min(L_s, L_m, L_l, L_f)
        self.pool_s = nn.AdaptiveAvgPool1d(target_L)
        self.pool_m = nn.AdaptiveAvgPool1d(target_L)
        self.pool_l = nn.AdaptiveAvgPool1d(target_L)
        self.pool_f = nn.AdaptiveAvgPool1d(target_L)
        self.out_len = target_L

        self.se = SEBlock(4 * mid)
        self.proj = nn.Sequential(
            nn.Conv1d(4 * mid, d_model, kernel_size=1),
            nn.BatchNorm1d(d_model), nn.GELU(),
        )

    def forward(self, x):
        fs = self.pool_s(self.small(x))
        fm = self.pool_m(self.medium(x))
        fl = self.pool_l(self.large(x))

        x_fft = torch.fft.rfft(x, dim=-1)
        x_mag = torch.abs(x_fft)
        if x_mag.shape[-1] < x.shape[-1]:
            pad = x.shape[-1] - x_mag.shape[-1]
            x_mag = F.pad(x_mag, (0, pad))
        else:
            x_mag = x_mag[..., :x.shape[-1]]
        ff = self.pool_f(self.spectral(x_mag))

        feat = torch.cat([fs, fm, fl, ff], dim=1)
        feat = self.se(feat)
        return self.proj(feat)


class BiLSTMTransformerBlock(nn.Module):
    def __init__(self, d_model=T_D_MODEL, n_heads=T_N_HEADS, dropout=T_DROPOUT):
        super().__init__()
        self.bilstm = nn.LSTM(
            d_model, d_model // 2, num_layers=1,
            batch_first=True, bidirectional=True
        )
        self.norm1 = nn.LayerNorm(d_model)
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=n_heads,
            dim_feedforward=d_model * 2, dropout=dropout,
            batch_first=True, activation='gelu'
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=1)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        lstm_out, _ = self.bilstm(x)
        x = self.norm1(x + lstm_out)
        attn_out = self.transformer(x)
        return self.norm2(x + attn_out)


class MultiScaleSleepNetPlain(nn.Module):
    """Teacher architecture -- identical to your trained checkpoints."""
    def __init__(self, in_ch=3, d_model=T_D_MODEL, n_layers=2,
                 dropout=T_DROPOUT, n_classes=5,
                 context=TEACHER_CONTEXT, window=TEACHER_WINDOW):
        super().__init__()
        self.context = context
        self.d_model = d_model
        self.cnn = MultiScaleCNN(in_ch=in_ch, d_model=d_model, dropout=dropout)
        self.intra_blocks = nn.Sequential(*[
            BiLSTMTransformerBlock(d_model, dropout=dropout) for _ in range(n_layers)
        ])
        self.inter_pos = nn.Parameter(torch.randn(1, window, d_model) * 0.01)
        self.inter_blocks = nn.Sequential(*[
            BiLSTMTransformerBlock(d_model, dropout=dropout) for _ in range(n_layers)
        ])
        self.classifier = nn.Sequential(
            nn.LayerNorm(d_model), nn.Linear(d_model, 64), nn.GELU(),
            nn.Dropout(dropout), nn.Linear(64, n_classes),
        )

    def forward(self, x):
        B, W, C, T = x.shape
        cnn_out = self.cnn(x.view(B * W, C, T)).permute(0, 2, 1)
        intra = self.intra_blocks(cnn_out)
        epoch_feat = intra.mean(dim=1).view(B, W, self.d_model)
        inter = self.inter_blocks(epoch_feat + self.inter_pos)
        center = inter[:, self.context, :]
        return self.classifier(center)


# ============================================================
# ========  STUDENT: PER-EPOCH ENCODER (identical to S5)  ========
# No architecture changes in this ablation -- ONLY the loss
# function changes (adaptive KD lambda). Model class is exactly
# S5's ContextStudentModel.
# ============================================================
class ZmaxEEGEncoder(nn.Module):
    def __init__(self, in_ch=2, d_model=S_D_MODEL, dropout=S_DROPOUT):
        super().__init__()
        mid = d_model // 2

        def branch(kernel):
            return nn.Sequential(
                nn.Conv1d(in_ch, mid, kernel_size=kernel, stride=4, padding=kernel // 2),
                nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(2, 2), nn.Dropout(dropout)
            )
        self.small, self.large = branch(15), branch(60)
        with torch.no_grad():
            dummy = torch.zeros(1, in_ch, 1920)
            L_s, L_l = self.small(dummy).shape[2], self.large(dummy).shape[2]
        target_L = min(L_s, L_l)
        self.pool_s = nn.AdaptiveAvgPool1d(target_L)
        self.pool_l = nn.AdaptiveAvgPool1d(target_L)
        self.proj = nn.Sequential(nn.Conv1d(2 * mid, d_model, kernel_size=1),
                                   nn.BatchNorm1d(d_model), nn.GELU())
        self.gru = nn.GRU(d_model, d_model // 2, batch_first=True, bidirectional=True)
        self.norm = nn.LayerNorm(d_model)

    def forward(self, x):
        # x: (N, 2, 1920) where N = B*W (flattened batch*window)
        fs, fl = self.pool_s(self.small(x)), self.pool_l(self.large(x))
        feat = self.proj(torch.cat([fs, fl], dim=1)).permute(0, 2, 1)
        gru_out, _ = self.gru(feat)
        return self.norm(feat.mean(dim=1) + gru_out.mean(dim=1))


class E4Encoder(nn.Module):
    def __init__(self, in_ch=3, d_model=S_D_MODEL, dropout=S_DROPOUT):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(in_ch, d_model // 2, kernel_size=15, stride=4, padding=7),
            nn.BatchNorm1d(d_model // 2), nn.GELU(), nn.MaxPool1d(2, 2),
            nn.Conv1d(d_model // 2, d_model, kernel_size=8, padding=4),
            nn.BatchNorm1d(d_model), nn.GELU(), nn.MaxPool1d(2, 2),
            nn.Dropout(dropout),
        )
        self.gru = nn.GRU(d_model, d_model // 2, batch_first=True, bidirectional=True)
        self.norm = nn.LayerNorm(d_model)

    def forward(self, x):
        feat = self.conv(x).permute(0, 2, 1)
        gru_out, _ = self.gru(feat)
        return self.norm(feat.mean(dim=1) + gru_out.mean(dim=1))


class InterEpochAggregator(nn.Module):
    def __init__(self, d_model=S_D_MODEL, context=STUDENT_CONTEXT):
        super().__init__()
        self.context = context
        self.gru = nn.GRU(d_model, d_model // 2, batch_first=True, bidirectional=True)
        self.norm = nn.LayerNorm(d_model)

    def forward(self, x):
        gru_out, _ = self.gru(x)
        contextualized = self.norm(x + gru_out)
        return contextualized[:, self.context, :]


class ContextStudentModel(nn.Module):
    """Identical to S5 -- no architecture changes in this ablation."""
    def __init__(self, d_model=S_D_MODEL, n_classes=5, dropout=S_DROPOUT, context=STUDENT_CONTEXT):
        super().__init__()
        self.context = context
        self.zmax_enc = ZmaxEEGEncoder(in_ch=2, d_model=d_model, dropout=dropout)
        self.e4_enc   = E4Encoder(in_ch=3, d_model=d_model, dropout=dropout)
        self.zmax_agg = InterEpochAggregator(d_model=d_model, context=context)
        self.e4_agg   = InterEpochAggregator(d_model=d_model, context=context)
        self.classifier = nn.Sequential(
            nn.LayerNorm(d_model * 2), nn.Linear(d_model * 2, 64), nn.GELU(),
            nn.Dropout(dropout), nn.Linear(64, n_classes)
        )

    def forward(self, zmax_x, e4_x):
        B, W, Cz, Tz = zmax_x.shape
        _, _, Ce, Te = e4_x.shape

        z_flat = self.zmax_enc(zmax_x.reshape(B * W, Cz, Tz)).view(B, W, -1)
        e_flat = self.e4_enc(e4_x.reshape(B * W, Ce, Te)).view(B, W, -1)

        z_ctx = self.zmax_agg(z_flat)
        e_ctx = self.e4_agg(e_flat)

        fused = torch.cat([z_ctx, e_ctx], dim=1)
        logits = self.classifier(fused)
        return logits


# ============================================================
# COMBINED DATASET (teacher window + student window + artifact_weight)
# ============================================================
class KDContextDataset(Dataset):
    def __init__(self, subject_list, psg_path, student_path,
                 teacher_context=TEACHER_CONTEXT, student_context=STUDENT_CONTEXT):
        self.teacher_context = teacher_context
        self.student_context = student_context
        self.data = []
        self.index = []

        skipped_mismatch = 0
        for sub in subject_list:
            psg_fp = os.path.join(psg_path, f"{sub}.npz")
            stu_fp = os.path.join(student_path, f"{sub}.npz")
            if not (os.path.exists(psg_fp) and os.path.exists(stu_fp)):
                continue

            with np.load(psg_fp) as d:
                eeg = d['eeg'][:, [0, 1], :]
                eog = d['eog'][:, [0], :]
                psg_signal = np.concatenate([eeg, eog], axis=1).astype(np.float32)
                psg_labels = d['labels'].copy()

            with np.load(stu_fp) as d:
                zmax_arr = d['zmax_eeg']
                e4_arr   = d['e4']
                stu_labels = d['labels'].copy()
                art_w = d['artifact_weight']

            n = min(len(psg_labels), len(stu_labels), zmax_arr.shape[0], e4_arr.shape[0])
            if abs(len(psg_labels) - len(stu_labels)) > 5:
                skipped_mismatch += 1

            sub_idx = len(self.data)
            self.data.append((psg_signal, psg_labels, zmax_arr, e4_arr, art_w, stu_labels, n))
            for i in range(n):
                self.index.append((sub_idx, i, n))

        print(f"  Subjects loaded: {len(self.data)}  (large mismatches: {skipped_mismatch})")
        print(f"  Samples: {len(self.index):,}")

    def __len__(self):
        return len(self.index)

    def __getitem__(self, idx):
        sub_idx, center_i, n = self.index[idx]
        psg_signal, psg_labels, zmax_arr, e4_arr, art_w, stu_labels, _ = self.data[sub_idx]

        psg_window = []
        for offset in range(-self.teacher_context, self.teacher_context + 1):
            ei = max(0, min(n - 1, center_i + offset))
            psg_window.append(psg_signal[ei])
        psg_x = np.stack(psg_window, axis=0)

        zmax_window, e4_window = [], []
        for offset in range(-self.student_context, self.student_context + 1):
            ei = max(0, min(n - 1, center_i + offset))
            zmax_window.append(zmax_arr[ei])
            e4_window.append(e4_arr[ei])
        zmax_x = np.stack(zmax_window, axis=0)
        e4_x   = np.stack(e4_window, axis=0)

        aw = float(art_w[center_i]) if center_i < len(art_w) else 1.0
        y  = int(stu_labels[center_i]) if center_i < len(stu_labels) else int(psg_labels[center_i])

        return (
            torch.FloatTensor(psg_x),
            torch.FloatTensor(zmax_x),
            torch.FloatTensor(e4_x),
            torch.tensor(aw, dtype=torch.float32),
            torch.tensor(y, dtype=torch.long),
        )


# ============================================================
# 3-WAY SPLIT + BUILD DATASETS
# ============================================================
_train_path = os.path.join(SPLIT_PATH, "_train_subs.npy")
_val_path   = os.path.join(SPLIT_PATH, "_val_subs.npy")
_test_path  = os.path.join(SPLIT_PATH, "_test_subs.npy")

for p, name in [(_train_path, "_train_subs.npy"),
                (_val_path,   "_val_subs.npy"),
                (_test_path,  "_test_subs.npy")]:
    if not os.path.exists(p):
        raise FileNotFoundError(f"{name} not found at {SPLIT_PATH}")

TRAIN_SUBS = np.load(_train_path, allow_pickle=True).tolist()
VAL_SUBS   = np.load(_val_path,   allow_pickle=True).tolist()
TEST_SUBS  = np.load(_test_path,  allow_pickle=True).tolist()

assert set(TRAIN_SUBS).isdisjoint(VAL_SUBS),  "TRAIN/VAL subject overlap!"
assert set(TRAIN_SUBS).isdisjoint(TEST_SUBS), "TRAIN/TEST subject overlap!"
assert set(VAL_SUBS).isdisjoint(TEST_SUBS),   "VAL/TEST subject overlap!"

print(f"Split loaded -> Train:{len(TRAIN_SUBS)}  Val:{len(VAL_SUBS)}  Test:{len(TEST_SUBS)}")

print("\nBuilding context-window KD datasets...")
print("Train:")
train_ds = KDContextDataset(TRAIN_SUBS, PSG_EEG_PATH, STUDENT_DATA_PATH)
print("Val:")
val_ds   = KDContextDataset(VAL_SUBS, PSG_EEG_PATH, STUDENT_DATA_PATH)
print("Test:")
test_ds  = KDContextDataset(TEST_SUBS, PSG_EEG_PATH, STUDENT_DATA_PATH)

for name, ds in [("train", train_ds), ("val", val_ds), ("test", test_ds)]:
    if len(ds) == 0:
        raise RuntimeError(f"{name}_ds has 0 samples! Check PSG_EEG_PATH / STUDENT_DATA_PATH.")
print("Datasets ready.")


# ============================================================
# LOAD FROZEN TEACHER ENSEMBLE
# ============================================================
print(f"\nLoading {len(TEACHER_SEEDS)} frozen teacher checkpoints from {TEACHER_CKPT_DIR}...")
teachers = []
for seed in TEACHER_SEEDS:
    ckpt = os.path.join(TEACHER_CKPT_DIR, f"best_seed{seed}.pt")
    if not os.path.exists(ckpt):
        print(f"  MISSING: {ckpt}")
        continue
    m = MultiScaleSleepNetPlain(in_ch=3, context=TEACHER_CONTEXT, window=TEACHER_WINDOW).to(device)
    m.load_state_dict(torch.load(ckpt, map_location=device))
    m.eval()
    for p in m.parameters():
        p.requires_grad = False
    teachers.append(m)
print(f"Loaded {len(teachers)} teacher models (frozen).")
if len(teachers) == 0:
    raise RuntimeError(f"No teacher checkpoints found in {TEACHER_CKPT_DIR}.")


@torch.no_grad()
def teacher_soft_targets(psg_x, temperature=KD_TEMPERATURE):
    probs_sum = None
    for m in teachers:
        logits = m(psg_x)
        probs = F.softmax(logits / temperature, dim=1)
        probs_sum = probs if probs_sum is None else probs_sum + probs
    return probs_sum / len(teachers)


# ============================================================
# CLASS WEIGHTS -- from TRAIN only
# ============================================================
all_train_labels = []
for _, _, _, _, _, labs, _ in train_ds.data:
    all_train_labels.extend(labs.tolist())
label_counts = np.array([Counter(all_train_labels).get(i, 1) for i in range(5)], dtype=np.float32)
cw = torch.FloatTensor(label_counts.sum() / (5 * label_counts)).to(device)
print(f"\nClass weights (from TRAIN set only): {dict(zip(LABEL_NAMES, cw.cpu().numpy().round(3)))}")


def set_seed(seed):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


# ============================================================
# LOSS: CE weighting identical to S4/S5. KD term now uses a
# PER-SAMPLE lambda that grows as artifact_weight shrinks
# (i.e. as the epoch gets noisier).
# ============================================================
def artifact_adaptive_kd_loss_fn(student_logits, teacher_probs, labels, artifact_weight,
                                  temperature, lam_base, alpha, class_weights):
    # ---- CE term: identical weighting logic to S4/S5 ----
    ce_per_sample = F.cross_entropy(student_logits, labels, weight=class_weights, reduction='none')
    weighted_ce = ce_per_sample * artifact_weight
    valid = artifact_weight > 0
    ce = weighted_ce[valid].mean() if valid.sum() > 0 else weighted_ce.mean()

    # ---- KD term: per-sample adaptive lambda ----
    # clean epoch (aw=1.0) -> lambda = lam_base (unchanged from S5)
    # noisy epoch (aw=0.0) -> lambda = lam_base * (1 + alpha)  (boosted)
    per_sample_lambda = lam_base * (1.0 + alpha * (1.0 - artifact_weight))

    student_log_probs = F.log_softmax(student_logits / temperature, dim=1)
    kd_per_sample = F.kl_div(
        student_log_probs, teacher_probs, reduction='none'
    ).sum(dim=1) * (temperature ** 2)
    kd = (kd_per_sample * per_sample_lambda).mean()

    total = ce + kd
    return total, kd.item(), ce.item(), per_sample_lambda.mean().item()


def train_epoch(model, loader, optimizer, scheduler):
    model.train()
    total_loss = total_kd = total_ce = total_lambda = 0
    preds, labs_all = [], []
    for psg_x, zmax_x, e4_x, aw, y in loader:
        psg_x, zmax_x, e4_x, aw, y = (
            psg_x.to(device), zmax_x.to(device), e4_x.to(device),
            aw.to(device), y.to(device)
        )
        optimizer.zero_grad()
        teacher_probs = teacher_soft_targets(psg_x)
        student_logits = model(zmax_x, e4_x)
        loss, kd_val, ce_val, mean_lambda = artifact_adaptive_kd_loss_fn(
            student_logits, teacher_probs, y, aw,
            KD_TEMPERATURE, KD_LAMBDA_BASE, ADAPTIVE_ALPHA, cw
        )
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()

        total_loss += loss.item(); total_kd += kd_val; total_ce += ce_val
        total_lambda += mean_lambda
        preds.extend(student_logits.argmax(1).cpu().numpy())
        labs_all.extend(y.cpu().numpy())

    n = len(loader)
    acc = accuracy_score(labs_all, preds)
    f1 = f1_score(labs_all, preds, average='macro', zero_division=0)
    return total_loss / n, total_kd / n, total_ce / n, total_lambda / n, acc, f1


@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    preds, labs_all = [], []
    for psg_x, zmax_x, e4_x, aw, y in loader:
        zmax_x, e4_x = zmax_x.to(device), e4_x.to(device)
        logits = model(zmax_x, e4_x)
        preds.extend(logits.argmax(1).cpu().numpy())
        labs_all.extend(y.numpy())
    preds, labs_all = np.array(preds), np.array(labs_all)
    acc = accuracy_score(labs_all, preds)
    f1 = f1_score(labs_all, preds, average='macro', zero_division=0)
    kappa = cohen_kappa_score(labs_all, preds)
    per_cls = f1_score(labs_all, preds, average=None, zero_division=0, labels=[0, 1, 2, 3, 4])
    return acc, f1, kappa, per_cls


# ============================================================
# CSV SETUP
# ============================================================
epoch_csv_path = os.path.join(EVAL_PATH, "epoch_log.csv")
epoch_fields = [
    "seed", "epoch", "train_loss", "train_ce", "train_kd", "train_mean_lambda",
    "train_acc", "train_f1_macro",
    "val_acc", "val_f1_macro", "val_kappa",
    "val_f1_Wake", "val_f1_N1", "val_f1_N2", "val_f1_N3", "val_f1_REM",
    "lr", "is_best",
]
with open(epoch_csv_path, 'w', newline='') as f:
    csv.DictWriter(f, epoch_fields).writeheader()

csv_path = os.path.join(EVAL_PATH, "summary.csv")
fields = ["seed", "best_epoch", "best_val_f1", "acc", "f1_macro", "kappa",
          "f1_Wake", "f1_N1", "f1_N2", "f1_N3", "f1_REM"]
with open(csv_path, 'w', newline='') as f:
    csv.DictWriter(f, fields).writeheader()

all_results = []
for seed_idx, seed in enumerate(SEEDS):
    print(f"\n{'='*60}\nSTUDENT SEED {seed}  ({seed_idx+1}/{len(SEEDS)})\n{'='*60}")
    set_seed(seed)

    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                               num_workers=0, generator=torch.Generator().manual_seed(seed))
    val_loader  = DataLoader(val_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
    test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

    model = ContextStudentModel(context=STUDENT_CONTEXT).to(device)
    n_params = sum(p.numel() for p in model.parameters())
    print(f"  Student parameters: {n_params:,}  (teacher frozen, not counted)")

    optimizer = optim.AdamW(model.parameters(), lr=5e-4, weight_decay=3e-4, betas=(0.9, 0.98), eps=1e-9)
    total_steps = N_EPOCHS * len(train_loader)
    warmup_steps = int(0.05 * total_steps)

    def warmup_cosine(step):
        if step < warmup_steps:
            return step / max(warmup_steps, 1)
        t = (step - warmup_steps) / max(total_steps - warmup_steps, 1)
        return 0.5 * (1 + math.cos(math.pi * t))

    scheduler = optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=warmup_cosine)

    best_val_f1 = 0.0
    best_epoch  = -1
    best_path = os.path.join(EVAL_PATH, f"best_student_seed{seed}.pt")

    for epoch in range(1, N_EPOCHS + 1):
        tr_loss, tr_kd, tr_ce, tr_lambda, tr_acc, tr_f1 = train_epoch(model, train_loader, optimizer, scheduler)
        vl_acc, vl_f1, vl_kap, vl_per = evaluate(model, val_loader)

        is_best = 0
        if vl_f1 > best_val_f1:
            best_val_f1 = vl_f1
            best_epoch  = epoch
            torch.save(model.state_dict(), best_path)
            is_best = 1

        tag = " <- BEST" if is_best else ""
        print(f"  Ep[{epoch:02d}/{N_EPOCHS}] Loss:{tr_loss:.3f}(CE:{tr_ce:.3f}+KD:{tr_kd:.3f}, meanLambda:{tr_lambda:.3f}) "
              f"TrF1:{tr_f1:.3f} | ValAcc:{vl_acc:.3f} ValF1:{vl_f1:.3f} Valk:{vl_kap:.3f}{tag}")

        with open(epoch_csv_path, 'a', newline='') as f:
            csv.DictWriter(f, epoch_fields).writerow({
                "seed": seed, "epoch": epoch,
                "train_loss": round(tr_loss, 6), "train_ce": round(tr_ce, 6),
                "train_kd": round(tr_kd, 6), "train_mean_lambda": round(tr_lambda, 6),
                "train_acc": round(tr_acc, 6), "train_f1_macro": round(tr_f1, 6),
                "val_acc": round(vl_acc, 6), "val_f1_macro": round(vl_f1, 6), "val_kappa": round(vl_kap, 6),
                "val_f1_Wake": round(vl_per[0], 6), "val_f1_N1": round(vl_per[1], 6),
                "val_f1_N2": round(vl_per[2], 6), "val_f1_N3": round(vl_per[3], 6),
                "val_f1_REM": round(vl_per[4], 6),
                "lr": optimizer.param_groups[0]['lr'], "is_best": is_best,
            })

    model.load_state_dict(torch.load(best_path, map_location=device))
    fin_acc, fin_f1, fin_kap, fin_per = evaluate(model, test_loader)

    print(f"\n  Seed {seed}: best val F1={best_val_f1:.4f} at epoch {best_epoch}")
    print(f"  Seed {seed} FINAL TEST (evaluated once): Acc={fin_acc*100:.2f}% F1={fin_f1:.4f} k={fin_kap:.4f}")
    for i, name in enumerate(LABEL_NAMES):
        print(f"    {name:6s}: {fin_per[i]:.4f}")

    all_results.append({'seed': seed, 'acc': fin_acc, 'f1': fin_f1, 'kappa': fin_kap, 'per_cls': fin_per,
                         'best_epoch': best_epoch, 'best_val_f1': best_val_f1})
    with open(csv_path, 'a', newline='') as f:
        csv.DictWriter(f, fields).writerow({
            "seed": seed, "best_epoch": best_epoch, "best_val_f1": round(best_val_f1, 4),
            "acc": round(fin_acc, 4), "f1_macro": round(fin_f1, 4), "kappa": round(fin_kap, 4),
            "f1_Wake": round(fin_per[0], 4), "f1_N1": round(fin_per[1], 4),
            "f1_N2": round(fin_per[2], 4), "f1_N3": round(fin_per[3], 4),
            "f1_REM": round(fin_per[4], 4),
        })

# ============================================================
# FINAL REPORT
# ============================================================
accs = np.array([r['acc'] for r in all_results]) * 100
f1s = np.array([r['f1'] for r in all_results])
kappas = np.array([r['kappa'] for r in all_results])
n1s = np.array([r['per_cls'][1] for r in all_results])

print(f"\n{'='*60}\nS6b: ARTIFACT-AWARE ADAPTIVE KD -- 5-SEED REPORT\n{'='*60}")
print(f"Accuracy : {accs.mean():.2f} +- {accs.std():.2f}%")
print(f"Macro F1 : {f1s.mean():.4f} +- {f1s.std():.4f}")
print(f"Kappa    : {kappas.mean():.4f} +- {kappas.std():.4f}")
print(f"N1 F1    : {n1s.mean():.4f} +- {n1s.std():.4f}")

print(f"\n{'='*60}\nCOMPARE AGAINST S5 BASELINE (constant KD lambda)\n{'='*60}")
print(f"{'Model':<45} {'Acc%':>8} {'F1':>8} {'N1 F1':>8}")
print("-" * 70)
print(f"{'S5 (context-window, constant KD lambda)':<45} {'65.98':>8} {'0.5974':>8} {'0.3514':>8}")
print(f"{'S6a (context-window, constant KD lambda)':<45} {'67.52':>8} {'0.6127':>8} {'0.3651':>8}")
print(f"{'S6b (adaptive KD, this run)':<45} {accs.mean():>8.2f} {f1s.mean():>8.4f} {n1s.mean():>8.4f}")
print("=" * 70)

diff_f1 = f1s.mean() - 0.5974
if diff_f1 > 0:
    print(f"\nS6b beats S5 by {diff_f1:+.4f} F1 -- adaptive KD weighting helped.")
    print("Worth keeping / reporting as an improvement.")
else:
    print(f"\nS6b does NOT beat S5 ({diff_f1:+.4f} F1). Report S5 as the final")
    print("result, and this as a negative ablation: boosting KD reliance on")
    print("noisy epochs did not outweigh the added training-time noise.")

print(f"\nEpoch log : {epoch_csv_path}")
print(f"Summary   : {csv_path}")
print("Done!")
# Out:
# Device        : cuda
# S6b: ARTIFACT-AWARE ADAPTIVE KD (dynamic per-sample KD weighting)
# Student context: +-5 (window=11)
# KD lambda base: 0.5   Temperature: 4.0   Adaptive alpha: 1.0
# Output        : D:\22\AA\AA journal\evaluation\teacher-student\s6b_artifact_adaptive_kd_studentC5
# Split loaded -> Train:65  Val:11  Test:20
#
# Building context-window KD datasets...
# Train:
#   Subjects loaded: 61  (large mismatches: 0)
#   Samples: 57,021
# Val:
#   Subjects loaded: 10  (large mismatches: 0)
#   Samples: 9,742
# Test:
#   Subjects loaded: 19  (large mismatches: 0)
#   Samples: 18,898
# Datasets ready.
#
# Loading 5 frozen teacher checkpoints from D:\22\AA\AA journal\evaluation\multiscale_plain_c7_valfixed...
# Loaded 5 teacher models (frozen).
#
# Class weights (from TRAIN set only): {'Wake': np.float32(2.094), 'N1': np.float32(3.192), 'N2': np.float32(0.436), 'N3': np.float32(1.0), 'REM': np.float32(1.092)}
#
# ============================================================
# STUDENT SEED 42  (1/5)
# ============================================================
#   Student parameters: 238,469  (teacher frozen, not counted)
#   Ep[01/30] Loss:5.640(CE:1.093+KD:4.546, meanLambda:0.661) TrF1:0.434 | ValAcc:0.561 ValF1:0.491 Valk:0.411 <- BEST
#   Ep[02/30] Loss:3.921(CE:0.890+KD:3.031, meanLambda:0.661) TrF1:0.589 | ValAcc:0.647 ValF1:0.577 Valk:0.514 <- BEST
#   Ep[03/30] Loss:3.201(CE:0.756+KD:2.445, meanLambda:0.661) TrF1:0.650 | ValAcc:0.650 ValF1:0.597 Valk:0.538 <- BEST
#   Ep[04/30] Loss:2.749(CE:0.668+KD:2.082, meanLambda:0.661) TrF1:0.682 | ValAcc:0.687 ValF1:0.636 Valk:0.582 <- BEST
#   Ep[05/30] Loss:2.437(CE:0.603+KD:1.834, meanLambda:0.661) TrF1:0.708 | ValAcc:0.686 ValF1:0.635 Valk:0.587
#   Ep[06/30] Loss:2.199(CE:0.556+KD:1.643, meanLambda:0.661) TrF1:0.726 | ValAcc:0.724 ValF1:0.666 Valk:0.632 <- BEST
#   Ep[07/30] Loss:2.038(CE:0.521+KD:1.518, meanLambda:0.661) TrF1:0.739 | ValAcc:0.710 ValF1:0.655 Valk:0.614
#   Ep[08/30] Loss:1.889(CE:0.495+KD:1.394, meanLambda:0.661) TrF1:0.754 | ValAcc:0.715 ValF1:0.659 Valk:0.621
#   Ep[09/30] Loss:1.766(CE:0.464+KD:1.302, meanLambda:0.661) TrF1:0.766 | ValAcc:0.729 ValF1:0.673 Valk:0.637 <- BEST
#   Ep[10/30] Loss:1.645(CE:0.442+KD:1.203, meanLambda:0.661) TrF1:0.776 | ValAcc:0.723 ValF1:0.665 Valk:0.630
#   Ep[11/30] Loss:1.553(CE:0.420+KD:1.133, meanLambda:0.661) TrF1:0.783 | ValAcc:0.715 ValF1:0.658 Valk:0.621
#   Ep[12/30] Loss:1.464(CE:0.397+KD:1.068, meanLambda:0.661) TrF1:0.793 | ValAcc:0.728 ValF1:0.665 Valk:0.633
#   Ep[13/30] Loss:1.386(CE:0.381+KD:1.005, meanLambda:0.661) TrF1:0.801 | ValAcc:0.725 ValF1:0.669 Valk:0.634
#   Ep[14/30] Loss:1.318(CE:0.360+KD:0.958, meanLambda:0.661) TrF1:0.805 | ValAcc:0.736 ValF1:0.677 Valk:0.648 <- BEST
#   Ep[15/30] Loss:1.251(CE:0.351+KD:0.900, meanLambda:0.661) TrF1:0.812 | ValAcc:0.717 ValF1:0.663 Valk:0.624
#   Ep[16/30] Loss:1.213(CE:0.343+KD:0.870, meanLambda:0.661) TrF1:0.816 | ValAcc:0.724 ValF1:0.666 Valk:0.630
#   Ep[17/30] Loss:1.155(CE:0.327+KD:0.828, meanLambda:0.661) TrF1:0.822 | ValAcc:0.723 ValF1:0.668 Valk:0.631
#   Ep[18/30] Loss:1.110(CE:0.317+KD:0.794, meanLambda:0.661) TrF1:0.825 | ValAcc:0.724 ValF1:0.666 Valk:0.632
#   Ep[19/30] Loss:1.071(CE:0.307+KD:0.764, meanLambda:0.661) TrF1:0.831 | ValAcc:0.729 ValF1:0.668 Valk:0.635
#   Ep[20/30] Loss:1.036(CE:0.298+KD:0.737, meanLambda:0.661) TrF1:0.834 | ValAcc:0.724 ValF1:0.665 Valk:0.631
#   Ep[21/30] Loss:1.004(CE:0.291+KD:0.713, meanLambda:0.661) TrF1:0.839 | ValAcc:0.723 ValF1:0.665 Valk:0.628
#   Ep[22/30] Loss:0.984(CE:0.284+KD:0.700, meanLambda:0.661) TrF1:0.839 | ValAcc:0.720 ValF1:0.664 Valk:0.627
#   Ep[23/30] Loss:0.963(CE:0.280+KD:0.683, meanLambda:0.661) TrF1:0.841 | ValAcc:0.711 ValF1:0.657 Valk:0.614
#   Ep[24/30] Loss:0.945(CE:0.276+KD:0.669, meanLambda:0.661) TrF1:0.844 | ValAcc:0.711 ValF1:0.656 Valk:0.614
#   Ep[25/30] Loss:0.919(CE:0.268+KD:0.651, meanLambda:0.661) TrF1:0.847 | ValAcc:0.715 ValF1:0.658 Valk:0.618
#   Ep[26/30] Loss:0.915(CE:0.267+KD:0.648, meanLambda:0.661) TrF1:0.848 | ValAcc:0.714 ValF1:0.659 Valk:0.618
#   Ep[27/30] Loss:0.908(CE:0.269+KD:0.639, meanLambda:0.661) TrF1:0.849 | ValAcc:0.714 ValF1:0.659 Valk:0.618
#   Ep[28/30] Loss:0.895(CE:0.262+KD:0.633, meanLambda:0.661) TrF1:0.849 | ValAcc:0.719 ValF1:0.664 Valk:0.625
#   Ep[29/30] Loss:0.889(CE:0.261+KD:0.628, meanLambda:0.661) TrF1:0.848 | ValAcc:0.711 ValF1:0.655 Valk:0.613
#   Ep[30/30] Loss:0.886(CE:0.260+KD:0.626, meanLambda:0.661) TrF1:0.852 | ValAcc:0.714 ValF1:0.658 Valk:0.618
#
#   Seed 42: best val F1=0.6771 at epoch 14
#   Seed 42 FINAL TEST (evaluated once): Acc=64.22% F1=0.5751 k=0.4954
#     Wake  : 0.5487
#     N1    : 0.3305
#     N2    : 0.7086
#     N3    : 0.5979
#     REM   : 0.6895
#
# ============================================================
# STUDENT SEED 123  (2/5)
# ============================================================
#   Student parameters: 238,469  (teacher frozen, not counted)
#   Ep[01/30] Loss:5.561(CE:1.123+KD:4.438, meanLambda:0.661) TrF1:0.427 | ValAcc:0.575 ValF1:0.502 Valk:0.428 <- BEST
#   Ep[02/30] Loss:3.907(CE:0.896+KD:3.010, meanLambda:0.661) TrF1:0.587 | ValAcc:0.623 ValF1:0.570 Valk:0.508 <- BEST
#   Ep[03/30] Loss:3.217(CE:0.760+KD:2.458, meanLambda:0.661) TrF1:0.642 | ValAcc:0.650 ValF1:0.602 Valk:0.536 <- BEST
#   Ep[04/30] Loss:2.748(CE:0.667+KD:2.081, meanLambda:0.661) TrF1:0.679 | ValAcc:0.656 ValF1:0.603 Valk:0.550 <- BEST
#   Ep[05/30] Loss:2.453(CE:0.610+KD:1.842, meanLambda:0.661) TrF1:0.706 | ValAcc:0.669 ValF1:0.616 Valk:0.562 <- BEST
#   Ep[06/30] Loss:2.228(CE:0.563+KD:1.665, meanLambda:0.661) TrF1:0.723 | ValAcc:0.703 ValF1:0.645 Valk:0.606 <- BEST
#   Ep[07/30] Loss:2.039(CE:0.519+KD:1.520, meanLambda:0.661) TrF1:0.742 | ValAcc:0.689 ValF1:0.633 Valk:0.587
#   Ep[08/30] Loss:1.873(CE:0.483+KD:1.390, meanLambda:0.661) TrF1:0.755 | ValAcc:0.688 ValF1:0.637 Valk:0.587
#   Ep[09/30] Loss:1.764(CE:0.461+KD:1.303, meanLambda:0.661) TrF1:0.765 | ValAcc:0.714 ValF1:0.655 Valk:0.619 <- BEST
#   Ep[10/30] Loss:1.649(CE:0.438+KD:1.211, meanLambda:0.661) TrF1:0.775 | ValAcc:0.719 ValF1:0.661 Valk:0.625 <- BEST
#   Ep[11/30] Loss:1.555(CE:0.415+KD:1.140, meanLambda:0.661) TrF1:0.783 | ValAcc:0.693 ValF1:0.642 Valk:0.596
#   Ep[12/30] Loss:1.458(CE:0.392+KD:1.065, meanLambda:0.661) TrF1:0.792 | ValAcc:0.716 ValF1:0.658 Valk:0.622
#   Ep[13/30] Loss:1.386(CE:0.378+KD:1.008, meanLambda:0.661) TrF1:0.799 | ValAcc:0.727 ValF1:0.669 Valk:0.636 <- BEST
#   Ep[14/30] Loss:1.333(CE:0.368+KD:0.965, meanLambda:0.661) TrF1:0.802 | ValAcc:0.724 ValF1:0.663 Valk:0.633
#   Ep[15/30] Loss:1.256(CE:0.350+KD:0.906, meanLambda:0.661) TrF1:0.811 | ValAcc:0.733 ValF1:0.669 Valk:0.642
#   Ep[16/30] Loss:1.203(CE:0.340+KD:0.863, meanLambda:0.661) TrF1:0.816 | ValAcc:0.725 ValF1:0.671 Valk:0.634 <- BEST
#   Ep[17/30] Loss:1.159(CE:0.326+KD:0.833, meanLambda:0.661) TrF1:0.819 | ValAcc:0.706 ValF1:0.654 Valk:0.613
#   Ep[18/30] Loss:1.117(CE:0.323+KD:0.794, meanLambda:0.661) TrF1:0.821 | ValAcc:0.727 ValF1:0.670 Valk:0.635
#   Ep[19/30] Loss:1.065(CE:0.304+KD:0.761, meanLambda:0.661) TrF1:0.828 | ValAcc:0.731 ValF1:0.671 Valk:0.642 <- BEST
#   Ep[20/30] Loss:1.035(CE:0.297+KD:0.738, meanLambda:0.661) TrF1:0.832 | ValAcc:0.715 ValF1:0.655 Valk:0.619
#   Ep[21/30] Loss:1.013(CE:0.294+KD:0.719, meanLambda:0.661) TrF1:0.834 | ValAcc:0.720 ValF1:0.662 Valk:0.626
#   Ep[22/30] Loss:0.990(CE:0.290+KD:0.700, meanLambda:0.661) TrF1:0.837 | ValAcc:0.716 ValF1:0.661 Valk:0.623
#   Ep[23/30] Loss:0.961(CE:0.279+KD:0.683, meanLambda:0.661) TrF1:0.839 | ValAcc:0.716 ValF1:0.658 Valk:0.622
#   Ep[24/30] Loss:0.953(CE:0.281+KD:0.672, meanLambda:0.661) TrF1:0.840 | ValAcc:0.701 ValF1:0.647 Valk:0.604
#   Ep[25/30] Loss:0.929(CE:0.274+KD:0.655, meanLambda:0.661) TrF1:0.842 | ValAcc:0.723 ValF1:0.663 Valk:0.630
#   Ep[26/30] Loss:0.912(CE:0.269+KD:0.644, meanLambda:0.661) TrF1:0.844 | ValAcc:0.702 ValF1:0.647 Valk:0.604
#   Ep[27/30] Loss:0.899(CE:0.264+KD:0.635, meanLambda:0.661) TrF1:0.845 | ValAcc:0.705 ValF1:0.650 Valk:0.609
#   Ep[28/30] Loss:0.896(CE:0.265+KD:0.631, meanLambda:0.661) TrF1:0.847 | ValAcc:0.705 ValF1:0.648 Valk:0.608
#   Ep[29/30] Loss:0.891(CE:0.263+KD:0.627, meanLambda:0.661) TrF1:0.846 | ValAcc:0.708 ValF1:0.652 Valk:0.613
#   Ep[30/30] Loss:0.882(CE:0.259+KD:0.623, meanLambda:0.661) TrF1:0.848 | ValAcc:0.710 ValF1:0.652 Valk:0.614
#
#   Seed 123: best val F1=0.6715 at epoch 19
#   Seed 123 FINAL TEST (evaluated once): Acc=65.60% F1=0.5933 k=0.5158
#     Wake  : 0.5978
#     N1    : 0.3244
#     N2    : 0.7069
#     N3    : 0.6463
#     REM   : 0.6910
#
# ============================================================
# STUDENT SEED 256  (3/5)
# ============================================================
#   Student parameters: 238,469  (teacher frozen, not counted)
#   Ep[01/30] Loss:5.610(CE:1.112+KD:4.498, meanLambda:0.661) TrF1:0.429 | ValAcc:0.582 ValF1:0.506 Valk:0.431 <- BEST
#   Ep[02/30] Loss:3.999(CE:0.907+KD:3.092, meanLambda:0.661) TrF1:0.579 | ValAcc:0.599 ValF1:0.551 Valk:0.472 <- BEST
#   Ep[03/30] Loss:3.253(CE:0.766+KD:2.486, meanLambda:0.661) TrF1:0.643 | ValAcc:0.630 ValF1:0.583 Valk:0.511 <- BEST
#   Ep[04/30] Loss:2.801(CE:0.673+KD:2.127, meanLambda:0.661) TrF1:0.678 | ValAcc:0.663 ValF1:0.609 Valk:0.552 <- BEST
#   Ep[05/30] Loss:2.475(CE:0.606+KD:1.869, meanLambda:0.661) TrF1:0.703 | ValAcc:0.664 ValF1:0.606 Valk:0.558
#   Ep[06/30] Loss:2.215(CE:0.554+KD:1.661, meanLambda:0.661) TrF1:0.725 | ValAcc:0.687 ValF1:0.635 Valk:0.583 <- BEST
#   Ep[07/30] Loss:2.044(CE:0.525+KD:1.519, meanLambda:0.661) TrF1:0.739 | ValAcc:0.681 ValF1:0.631 Valk:0.580
#   Ep[08/30] Loss:1.889(CE:0.490+KD:1.399, meanLambda:0.661) TrF1:0.753 | ValAcc:0.685 ValF1:0.626 Valk:0.581
#   Ep[09/30] Loss:1.765(CE:0.462+KD:1.303, meanLambda:0.661) TrF1:0.765 | ValAcc:0.689 ValF1:0.645 Valk:0.593 <- BEST
#   Ep[10/30] Loss:1.652(CE:0.445+KD:1.207, meanLambda:0.661) TrF1:0.774 | ValAcc:0.707 ValF1:0.652 Valk:0.612 <- BEST
#   Ep[11/30] Loss:1.549(CE:0.419+KD:1.130, meanLambda:0.661) TrF1:0.783 | ValAcc:0.714 ValF1:0.656 Valk:0.617 <- BEST
#   Ep[12/30] Loss:1.459(CE:0.398+KD:1.062, meanLambda:0.661) TrF1:0.789 | ValAcc:0.711 ValF1:0.652 Valk:0.614
#   Ep[13/30] Loss:1.376(CE:0.379+KD:0.997, meanLambda:0.661) TrF1:0.800 | ValAcc:0.713 ValF1:0.653 Valk:0.615
#   Ep[14/30] Loss:1.310(CE:0.363+KD:0.948, meanLambda:0.661) TrF1:0.807 | ValAcc:0.712 ValF1:0.657 Valk:0.615 <- BEST
#   Ep[15/30] Loss:1.253(CE:0.348+KD:0.905, meanLambda:0.661) TrF1:0.811 | ValAcc:0.718 ValF1:0.664 Valk:0.623 <- BEST
#   Ep[16/30] Loss:1.198(CE:0.335+KD:0.863, meanLambda:0.661) TrF1:0.814 | ValAcc:0.717 ValF1:0.660 Valk:0.623
#   Ep[17/30] Loss:1.161(CE:0.332+KD:0.829, meanLambda:0.661) TrF1:0.821 | ValAcc:0.733 ValF1:0.670 Valk:0.640 <- BEST
#   Ep[18/30] Loss:1.109(CE:0.315+KD:0.794, meanLambda:0.661) TrF1:0.826 | ValAcc:0.712 ValF1:0.657 Valk:0.617
#   Ep[19/30] Loss:1.072(CE:0.308+KD:0.764, meanLambda:0.661) TrF1:0.829 | ValAcc:0.719 ValF1:0.661 Valk:0.624
#   Ep[20/30] Loss:1.029(CE:0.296+KD:0.733, meanLambda:0.661) TrF1:0.832 | ValAcc:0.717 ValF1:0.660 Valk:0.622
#   Ep[21/30] Loss:1.003(CE:0.293+KD:0.710, meanLambda:0.661) TrF1:0.834 | ValAcc:0.715 ValF1:0.658 Valk:0.620
#   Ep[22/30] Loss:0.975(CE:0.283+KD:0.691, meanLambda:0.661) TrF1:0.837 | ValAcc:0.718 ValF1:0.656 Valk:0.622
#   Ep[23/30] Loss:0.966(CE:0.277+KD:0.688, meanLambda:0.661) TrF1:0.839 | ValAcc:0.717 ValF1:0.655 Valk:0.621
#   Ep[24/30] Loss:0.935(CE:0.269+KD:0.665, meanLambda:0.661) TrF1:0.844 | ValAcc:0.708 ValF1:0.649 Valk:0.611
#   Ep[25/30] Loss:0.922(CE:0.267+KD:0.655, meanLambda:0.661) TrF1:0.845 | ValAcc:0.721 ValF1:0.660 Valk:0.626
#   Ep[26/30] Loss:0.910(CE:0.264+KD:0.646, meanLambda:0.661) TrF1:0.846 | ValAcc:0.721 ValF1:0.660 Valk:0.626
#   Ep[27/30] Loss:0.900(CE:0.262+KD:0.638, meanLambda:0.661) TrF1:0.847 | ValAcc:0.707 ValF1:0.649 Valk:0.608
#   Ep[28/30] Loss:0.883(CE:0.258+KD:0.625, meanLambda:0.661) TrF1:0.849 | ValAcc:0.712 ValF1:0.652 Valk:0.614
#   Ep[29/30] Loss:0.880(CE:0.256+KD:0.624, meanLambda:0.661) TrF1:0.849 | ValAcc:0.718 ValF1:0.657 Valk:0.622
#   Ep[30/30] Loss:0.884(CE:0.258+KD:0.626, meanLambda:0.661) TrF1:0.849 | ValAcc:0.719 ValF1:0.660 Valk:0.624
#
#   Seed 256: best val F1=0.6700 at epoch 17
#   Seed 256 FINAL TEST (evaluated once): Acc=65.07% F1=0.5853 k=0.5051
#     Wake  : 0.5318
#     N1    : 0.3756
#     N2    : 0.7204
#     N3    : 0.6071
#     REM   : 0.6916
#
# ============================================================
# STUDENT SEED 789  (4/5)
# ============================================================
#   Student parameters: 238,469  (teacher frozen, not counted)
#   Ep[01/30] Loss:5.617(CE:1.116+KD:4.501, meanLambda:0.661) TrF1:0.423 | ValAcc:0.589 ValF1:0.515 Valk:0.444 <- BEST
#   Ep[02/30] Loss:3.920(CE:0.892+KD:3.027, meanLambda:0.661) TrF1:0.584 | ValAcc:0.614 ValF1:0.555 Valk:0.486 <- BEST
#   Ep[03/30] Loss:3.175(CE:0.756+KD:2.419, meanLambda:0.661) TrF1:0.648 | ValAcc:0.654 ValF1:0.602 Valk:0.543 <- BEST
#   Ep[04/30] Loss:2.723(CE:0.660+KD:2.063, meanLambda:0.661) TrF1:0.681 | ValAcc:0.678 ValF1:0.623 Valk:0.573 <- BEST
#   Ep[05/30] Loss:2.428(CE:0.600+KD:1.828, meanLambda:0.661) TrF1:0.707 | ValAcc:0.697 ValF1:0.645 Valk:0.596 <- BEST
#   Ep[06/30] Loss:2.196(CE:0.554+KD:1.642, meanLambda:0.661) TrF1:0.727 | ValAcc:0.713 ValF1:0.654 Valk:0.616 <- BEST
#   Ep[07/30] Loss:2.018(CE:0.514+KD:1.504, meanLambda:0.661) TrF1:0.742 | ValAcc:0.696 ValF1:0.636 Valk:0.594
#   Ep[08/30] Loss:1.886(CE:0.492+KD:1.394, meanLambda:0.661) TrF1:0.755 | ValAcc:0.707 ValF1:0.654 Valk:0.609 <- BEST
#   Ep[09/30] Loss:1.757(CE:0.464+KD:1.293, meanLambda:0.661) TrF1:0.763 | ValAcc:0.715 ValF1:0.662 Valk:0.620 <- BEST
#   Ep[10/30] Loss:1.656(CE:0.440+KD:1.216, meanLambda:0.661) TrF1:0.774 | ValAcc:0.714 ValF1:0.656 Valk:0.616
#   Ep[11/30] Loss:1.571(CE:0.422+KD:1.149, meanLambda:0.661) TrF1:0.782 | ValAcc:0.713 ValF1:0.653 Valk:0.616
#   Ep[12/30] Loss:1.493(CE:0.408+KD:1.085, meanLambda:0.661) TrF1:0.789 | ValAcc:0.715 ValF1:0.658 Valk:0.617
#   Ep[13/30] Loss:1.409(CE:0.389+KD:1.021, meanLambda:0.661) TrF1:0.795 | ValAcc:0.725 ValF1:0.666 Valk:0.630 <- BEST
#   Ep[14/30] Loss:1.350(CE:0.373+KD:0.977, meanLambda:0.661) TrF1:0.801 | ValAcc:0.738 ValF1:0.677 Valk:0.648 <- BEST
#   Ep[15/30] Loss:1.289(CE:0.361+KD:0.929, meanLambda:0.661) TrF1:0.809 | ValAcc:0.726 ValF1:0.663 Valk:0.630
#   Ep[16/30] Loss:1.231(CE:0.341+KD:0.890, meanLambda:0.661) TrF1:0.815 | ValAcc:0.722 ValF1:0.666 Valk:0.629
#   Ep[17/30] Loss:1.193(CE:0.339+KD:0.854, meanLambda:0.661) TrF1:0.818 | ValAcc:0.710 ValF1:0.654 Valk:0.614
#   Ep[18/30] Loss:1.132(CE:0.323+KD:0.810, meanLambda:0.661) TrF1:0.824 | ValAcc:0.714 ValF1:0.657 Valk:0.617
#   Ep[19/30] Loss:1.098(CE:0.314+KD:0.784, meanLambda:0.661) TrF1:0.826 | ValAcc:0.719 ValF1:0.660 Valk:0.625
#   Ep[20/30] Loss:1.067(CE:0.306+KD:0.761, meanLambda:0.661) TrF1:0.832 | ValAcc:0.716 ValF1:0.655 Valk:0.620
#   Ep[21/30] Loss:1.026(CE:0.295+KD:0.731, meanLambda:0.661) TrF1:0.837 | ValAcc:0.716 ValF1:0.657 Valk:0.620
#   Ep[22/30] Loss:1.016(CE:0.295+KD:0.721, meanLambda:0.661) TrF1:0.834 | ValAcc:0.721 ValF1:0.659 Valk:0.625
#   Ep[23/30] Loss:0.981(CE:0.286+KD:0.695, meanLambda:0.661) TrF1:0.838 | ValAcc:0.719 ValF1:0.657 Valk:0.622
#   Ep[24/30] Loss:0.967(CE:0.283+KD:0.684, meanLambda:0.661) TrF1:0.841 | ValAcc:0.722 ValF1:0.662 Valk:0.628
#   Ep[25/30] Loss:0.946(CE:0.276+KD:0.670, meanLambda:0.661) TrF1:0.844 | ValAcc:0.720 ValF1:0.653 Valk:0.621
#   Ep[26/30] Loss:0.934(CE:0.274+KD:0.661, meanLambda:0.661) TrF1:0.845 | ValAcc:0.712 ValF1:0.649 Valk:0.613
#   Ep[27/30] Loss:0.925(CE:0.271+KD:0.654, meanLambda:0.661) TrF1:0.846 | ValAcc:0.718 ValF1:0.656 Valk:0.621
#   Ep[28/30] Loss:0.922(CE:0.270+KD:0.653, meanLambda:0.661) TrF1:0.845 | ValAcc:0.719 ValF1:0.655 Valk:0.623
#   Ep[29/30] Loss:0.910(CE:0.270+KD:0.640, meanLambda:0.661) TrF1:0.846 | ValAcc:0.712 ValF1:0.650 Valk:0.613
#   Ep[30/30] Loss:0.913(CE:0.268+KD:0.645, meanLambda:0.661) TrF1:0.847 | ValAcc:0.715 ValF1:0.652 Valk:0.616
#
#   Seed 789: best val F1=0.6767 at epoch 14
#   Seed 789 FINAL TEST (evaluated once): Acc=68.01% F1=0.6128 k=0.5375
#     Wake  : 0.6184
#     N1    : 0.3526
#     N2    : 0.7427
#     N3    : 0.6416
#     REM   : 0.7088
#
# ============================================================
# STUDENT SEED 999  (5/5)
# ============================================================
#   Student parameters: 238,469  (teacher frozen, not counted)
#   Ep[01/30] Loss:5.570(CE:1.114+KD:4.457, meanLambda:0.661) TrF1:0.426 | ValAcc:0.570 ValF1:0.498 Valk:0.420 <- BEST
#   Ep[02/30] Loss:4.006(CE:0.914+KD:3.092, meanLambda:0.661) TrF1:0.579 | ValAcc:0.621 ValF1:0.569 Valk:0.496 <- BEST
#   Ep[03/30] Loss:3.235(CE:0.756+KD:2.479, meanLambda:0.661) TrF1:0.644 | ValAcc:0.693 ValF1:0.630 Valk:0.582 <- BEST
#   Ep[04/30] Loss:2.756(CE:0.663+KD:2.093, meanLambda:0.661) TrF1:0.681 | ValAcc:0.699 ValF1:0.643 Valk:0.596 <- BEST
#   Ep[05/30] Loss:2.438(CE:0.599+KD:1.838, meanLambda:0.661) TrF1:0.710 | ValAcc:0.703 ValF1:0.651 Valk:0.604 <- BEST
#   Ep[06/30] Loss:2.223(CE:0.557+KD:1.666, meanLambda:0.661) TrF1:0.730 | ValAcc:0.702 ValF1:0.648 Valk:0.605
#   Ep[07/30] Loss:2.028(CE:0.515+KD:1.514, meanLambda:0.661) TrF1:0.745 | ValAcc:0.692 ValF1:0.638 Valk:0.592
#   Ep[08/30] Loss:1.885(CE:0.491+KD:1.393, meanLambda:0.661) TrF1:0.756 | ValAcc:0.706 ValF1:0.653 Valk:0.609 <- BEST
#   Ep[09/30] Loss:1.771(CE:0.465+KD:1.306, meanLambda:0.661) TrF1:0.767 | ValAcc:0.707 ValF1:0.652 Valk:0.612
#   Ep[10/30] Loss:1.665(CE:0.442+KD:1.223, meanLambda:0.661) TrF1:0.775 | ValAcc:0.724 ValF1:0.667 Valk:0.634 <- BEST
#   Ep[11/30] Loss:1.554(CE:0.414+KD:1.140, meanLambda:0.661) TrF1:0.784 | ValAcc:0.698 ValF1:0.651 Valk:0.605
#   Ep[12/30] Loss:1.472(CE:0.399+KD:1.074, meanLambda:0.661) TrF1:0.791 | ValAcc:0.727 ValF1:0.671 Valk:0.634 <- BEST
#   Ep[13/30] Loss:1.406(CE:0.382+KD:1.024, meanLambda:0.661) TrF1:0.799 | ValAcc:0.735 ValF1:0.680 Valk:0.646 <- BEST
#   Ep[14/30] Loss:1.334(CE:0.368+KD:0.967, meanLambda:0.661) TrF1:0.806 | ValAcc:0.740 ValF1:0.687 Valk:0.651 <- BEST
#   Ep[15/30] Loss:1.270(CE:0.351+KD:0.919, meanLambda:0.661) TrF1:0.811 | ValAcc:0.714 ValF1:0.661 Valk:0.619
#   Ep[16/30] Loss:1.225(CE:0.345+KD:0.881, meanLambda:0.661) TrF1:0.816 | ValAcc:0.713 ValF1:0.668 Valk:0.620
#   Ep[17/30] Loss:1.173(CE:0.328+KD:0.845, meanLambda:0.661) TrF1:0.823 | ValAcc:0.720 ValF1:0.667 Valk:0.625
#   Ep[18/30] Loss:1.122(CE:0.315+KD:0.807, meanLambda:0.661) TrF1:0.826 | ValAcc:0.725 ValF1:0.672 Valk:0.633
#   Ep[19/30] Loss:1.102(CE:0.315+KD:0.787, meanLambda:0.661) TrF1:0.830 | ValAcc:0.720 ValF1:0.671 Valk:0.629
#   Ep[20/30] Loss:1.056(CE:0.299+KD:0.756, meanLambda:0.661) TrF1:0.836 | ValAcc:0.726 ValF1:0.674 Valk:0.637
#   Ep[21/30] Loss:1.023(CE:0.290+KD:0.733, meanLambda:0.661) TrF1:0.837 | ValAcc:0.713 ValF1:0.667 Valk:0.619
#   Ep[22/30] Loss:0.996(CE:0.284+KD:0.712, meanLambda:0.661) TrF1:0.838 | ValAcc:0.717 ValF1:0.668 Valk:0.624
#   Ep[23/30] Loss:0.978(CE:0.281+KD:0.698, meanLambda:0.661) TrF1:0.842 | ValAcc:0.717 ValF1:0.668 Valk:0.625
#   Ep[24/30] Loss:0.958(CE:0.277+KD:0.681, meanLambda:0.661) TrF1:0.844 | ValAcc:0.713 ValF1:0.668 Valk:0.620
#   Ep[25/30] Loss:0.936(CE:0.270+KD:0.667, meanLambda:0.661) TrF1:0.846 | ValAcc:0.715 ValF1:0.666 Valk:0.620
#   Ep[26/30] Loss:0.929(CE:0.271+KD:0.658, meanLambda:0.661) TrF1:0.844 | ValAcc:0.710 ValF1:0.663 Valk:0.616
#   Ep[27/30] Loss:0.916(CE:0.266+KD:0.649, meanLambda:0.661) TrF1:0.846 | ValAcc:0.720 ValF1:0.671 Valk:0.627
#   Ep[28/30] Loss:0.914(CE:0.265+KD:0.649, meanLambda:0.661) TrF1:0.847 | ValAcc:0.718 ValF1:0.669 Valk:0.625
#   Ep[29/30] Loss:0.901(CE:0.262+KD:0.639, meanLambda:0.661) TrF1:0.848 | ValAcc:0.716 ValF1:0.666 Valk:0.622
#   Ep[30/30] Loss:0.905(CE:0.261+KD:0.644, meanLambda:0.661) TrF1:0.849 | ValAcc:0.715 ValF1:0.665 Valk:0.621
#
#   Seed 999: best val F1=0.6867 at epoch 14
#   Seed 999 FINAL TEST (evaluated once): Acc=66.51% F1=0.6004 k=0.5246
#     Wake  : 0.5653
#     N1    : 0.3643
#     N2    : 0.7290
#     N3    : 0.6325
#     REM   : 0.7109
#
# ============================================================
# S6b: ARTIFACT-AWARE ADAPTIVE KD -- 5-SEED REPORT
# ============================================================
# Accuracy : 65.88 +- 1.30%
# Macro F1 : 0.5934 +- 0.0129
# Kappa    : 0.5157 +- 0.0147
# N1 F1    : 0.3495 +- 0.0195
#
# ============================================================
# COMPARE AGAINST S5 BASELINE (constant KD lambda)
# ============================================================
# Model                                             Acc%       F1    N1 F1
# ----------------------------------------------------------------------
# S5 (context-window, constant KD lambda)          65.98   0.5974   0.3514
# S6a (context-window, constant KD lambda)         67.52   0.6127   0.3651
# S6b (adaptive KD, this run)                      65.88   0.5934   0.3495
# ======================================================================
#
# S6b does NOT beat S5 (-0.0040 F1). Report S5 as the final
# result, and this as a negative ablation: boosting KD reliance on
# noisy epochs did not outweigh the added training-time noise.
#
# Epoch log : D:\22\AA\AA journal\evaluation\teacher-student\s6b_artifact_adaptive_kd_studentC5\epoch_log.csv
# Summary   : D:\22\AA\AA journal\evaluation\teacher-student\s6b_artifact_adaptive_kd_studentC5\summary.csv
# Done!
