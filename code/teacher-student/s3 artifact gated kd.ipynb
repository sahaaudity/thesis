# %%
# ============================================================
# S3: ARTIFACT-CONDITIONED GATED FUSION STUDENT + KD
#
# Identical to S2 (KD from frozen PSG teacher), except the
# fusion mechanism changes from simple concatenation to an
# artifact-conditioned GATE:
#
#   Zmax EEG --> ZmaxEEGEncoder --> z (96-dim)  --\
#                                                   >-- Gate(z, e, artifact_weight)
#   E4       --> E4Encoder      --> e (96-dim)  --/         |
#                                                            v
#                                               fused = gate*z + (1-gate)*e
#                                                            |
#                                                            v
#                                                       Classifier
#
# Loss (still plain CE + KD -- artifact-WEIGHTED loss is S4,
# not this script):
#   L = L_CE + lambda_KD * L_KD
#
# Compare against S2 (F1=0.5219) to isolate the effect of
# artifact-aware fusion alone.
# ============================================================

import os
import csv
import math
import random
import warnings
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from collections import Counter
from sklearn.metrics import accuracy_score, f1_score, cohen_kappa_score
warnings.filterwarnings('ignore')

# ============================================================
# PATHS
# ============================================================
PSG_EEG_PATH      = r"D:\22\AA\preprocess\preprocessed_FFinal"
STUDENT_DATA_PATH = r"D:\22\AA\preprocess\preprocessed_student_zmax_e4"
TEACHER_CKPT_DIR  = r"D:\22\AA\evaluation\multiscale_plain_c7_88%"
EVAL_PATH         = r"D:\22\AA\evaluation\teacher-student\s3_artifact_gated_kd"
os.makedirs(EVAL_PATH, exist_ok=True)

LABEL_NAMES = ["Wake", "N1", "N2", "N3", "REM"]
CONTEXT     = 7
WINDOW      = 2 * CONTEXT + 1
N_EPOCHS    = 30
BATCH_SIZE  = 64
SEEDS         = [42, 123, 256, 789, 999]
TEACHER_SEEDS = [42, 123, 256, 789, 999]

T_D_MODEL = 128
T_DROPOUT = 0.4
T_N_HEADS = 4

S_D_MODEL = 96
S_DROPOUT = 0.3

KD_LAMBDA      = 1.0
KD_TEMPERATURE = 3.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device        : {device}")
print(f"S3: Artifact-conditioned gated fusion + KD (no artifact loss weighting yet)")
print(f"KD lambda     : {KD_LAMBDA}   Temperature: {KD_TEMPERATURE}")
print(f"Teacher       : MultiScaleSleepNetPlain, 5-seed ensemble (frozen)")
print(f"Student       : ArtifactGatedStudentModel (gate replaces concat)")
print(f"Output        : {EVAL_PATH}")


# ============================================================
# ============  TEACHER ARCHITECTURE (frozen)  ================
# ============================================================
class SEBlock(nn.Module):
    def __init__(self, channels, reduction=8):
        super().__init__()
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Sequential(
            nn.Linear(channels, channels // reduction), nn.ReLU(),
            nn.Linear(channels // reduction, channels), nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _ = x.shape
        s = self.pool(x).view(b, c)
        s = self.fc(s).view(b, c, 1)
        return x * s


class MultiScaleCNN(nn.Module):
    def __init__(self, in_ch=3, d_model=T_D_MODEL, dropout=T_DROPOUT):
        super().__init__()
        mid = d_model // 4

        def time_branch(kernel):
            return nn.Sequential(
                nn.Conv1d(in_ch, mid, kernel_size=kernel, stride=6, padding=kernel // 2),
                nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(4, 4),
                nn.Conv1d(mid, mid, kernel_size=8, padding=4),
                nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(2, 2),
                nn.Dropout(dropout),
            )

        self.small  = time_branch(25)
        self.medium = time_branch(50)
        self.large  = time_branch(100)

        self.spectral = nn.Sequential(
            nn.Conv1d(in_ch, mid, kernel_size=25, stride=6, padding=12),
            nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(4, 4),
            nn.Conv1d(mid, mid, kernel_size=8, padding=4),
            nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(2, 2),
            nn.Dropout(dropout),
        )

        with torch.no_grad():
            dummy = torch.zeros(1, in_ch, 3000)
            L_s = self.small(dummy).shape[2]
            L_m = self.medium(dummy).shape[2]
            L_l = self.large(dummy).shape[2]
            L_f = self.spectral(dummy).shape[2]

        target_L = min(L_s, L_m, L_l, L_f)
        self.pool_s = nn.AdaptiveAvgPool1d(target_L)
        self.pool_m = nn.AdaptiveAvgPool1d(target_L)
        self.pool_l = nn.AdaptiveAvgPool1d(target_L)
        self.pool_f = nn.AdaptiveAvgPool1d(target_L)
        self.out_len = target_L

        self.se = SEBlock(4 * mid)
        self.proj = nn.Sequential(
            nn.Conv1d(4 * mid, d_model, kernel_size=1),
            nn.BatchNorm1d(d_model), nn.GELU(),
        )

    def forward(self, x):
        fs = self.pool_s(self.small(x))
        fm = self.pool_m(self.medium(x))
        fl = self.pool_l(self.large(x))

        x_fft = torch.fft.rfft(x, dim=-1)
        x_mag = torch.abs(x_fft)
        if x_mag.shape[-1] < x.shape[-1]:
            pad = x.shape[-1] - x_mag.shape[-1]
            x_mag = F.pad(x_mag, (0, pad))
        else:
            x_mag = x_mag[..., :x.shape[-1]]
        ff = self.pool_f(self.spectral(x_mag))

        feat = torch.cat([fs, fm, fl, ff], dim=1)
        feat = self.se(feat)
        return self.proj(feat)


class BiLSTMTransformerBlock(nn.Module):
    def __init__(self, d_model=T_D_MODEL, n_heads=T_N_HEADS, dropout=T_DROPOUT):
        super().__init__()
        self.bilstm = nn.LSTM(
            d_model, d_model // 2, num_layers=1,
            batch_first=True, bidirectional=True
        )
        self.norm1 = nn.LayerNorm(d_model)
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, nhead=n_heads,
            dim_feedforward=d_model * 2, dropout=dropout,
            batch_first=True, activation='gelu'
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=1)
        self.norm2 = nn.LayerNorm(d_model)

    def forward(self, x):
        lstm_out, _ = self.bilstm(x)
        x = self.norm1(x + lstm_out)
        attn_out = self.transformer(x)
        return self.norm2(x + attn_out)


class MultiScaleSleepNetPlain(nn.Module):
    """Teacher architecture -- identical to your trained checkpoints."""
    def __init__(self, in_ch=3, d_model=T_D_MODEL, n_layers=2,
                 dropout=T_DROPOUT, n_classes=5, context=CONTEXT):
        super().__init__()
        self.context = context
        self.d_model = d_model
        self.cnn = MultiScaleCNN(in_ch=in_ch, d_model=d_model, dropout=dropout)
        self.intra_blocks = nn.Sequential(*[
            BiLSTMTransformerBlock(d_model, dropout=dropout) for _ in range(n_layers)
        ])
        self.inter_pos = nn.Parameter(torch.randn(1, WINDOW, d_model) * 0.01)
        self.inter_blocks = nn.Sequential(*[
            BiLSTMTransformerBlock(d_model, dropout=dropout) for _ in range(n_layers)
        ])
        self.classifier = nn.Sequential(
            nn.LayerNorm(d_model), nn.Linear(d_model, 64), nn.GELU(),
            nn.Dropout(dropout), nn.Linear(64, n_classes),
        )

    def forward(self, x):
        B, W, C, T = x.shape
        cnn_out = self.cnn(x.view(B * W, C, T)).permute(0, 2, 1)
        intra = self.intra_blocks(cnn_out)
        epoch_feat = intra.mean(dim=1).view(B, W, self.d_model)
        inter = self.inter_blocks(epoch_feat + self.inter_pos)
        center = inter[:, self.context, :]
        return self.classifier(center)


# ============================================================
# ============  STUDENT ARCHITECTURE (gated fusion)  ===========
# ============================================================
class ZmaxEEGEncoder(nn.Module):
    def __init__(self, in_ch=2, d_model=S_D_MODEL, dropout=S_DROPOUT):
        super().__init__()
        mid = d_model // 2

        def branch(kernel):
            return nn.Sequential(
                nn.Conv1d(in_ch, mid, kernel_size=kernel, stride=4, padding=kernel // 2),
                nn.BatchNorm1d(mid), nn.GELU(), nn.MaxPool1d(2, 2), nn.Dropout(dropout)
            )
        self.small, self.large = branch(15), branch(60)
        with torch.no_grad():
            dummy = torch.zeros(1, in_ch, 1920)
            L_s, L_l = self.small(dummy).shape[2], self.large(dummy).shape[2]
        target_L = min(L_s, L_l)
        self.pool_s = nn.AdaptiveAvgPool1d(target_L)
        self.pool_l = nn.AdaptiveAvgPool1d(target_L)
        self.proj = nn.Sequential(nn.Conv1d(2 * mid, d_model, kernel_size=1),
                                   nn.BatchNorm1d(d_model), nn.GELU())
        self.gru = nn.GRU(d_model, d_model // 2, batch_first=True, bidirectional=True)
        self.norm = nn.LayerNorm(d_model)

    def forward(self, x):
        fs, fl = self.pool_s(self.small(x)), self.pool_l(self.large(x))
        feat = self.proj(torch.cat([fs, fl], dim=1)).permute(0, 2, 1)
        gru_out, _ = self.gru(feat)
        return self.norm(feat.mean(dim=1) + gru_out.mean(dim=1))


class E4Encoder(nn.Module):
    def __init__(self, in_ch=3, d_model=S_D_MODEL, dropout=S_DROPOUT):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(in_ch, d_model // 2, kernel_size=15, stride=4, padding=7),
            nn.BatchNorm1d(d_model // 2), nn.GELU(), nn.MaxPool1d(2, 2),
            nn.Conv1d(d_model // 2, d_model, kernel_size=8, padding=4),
            nn.BatchNorm1d(d_model), nn.GELU(), nn.MaxPool1d(2, 2),
            nn.Dropout(dropout),
        )
        self.gru = nn.GRU(d_model, d_model // 2, batch_first=True, bidirectional=True)
        self.norm = nn.LayerNorm(d_model)

    def forward(self, x):
        feat = self.conv(x).permute(0, 2, 1)
        gru_out, _ = self.gru(feat)
        return self.norm(feat.mean(dim=1) + gru_out.mean(dim=1))


class ArtifactGatedFusion(nn.Module):
    """
    Gate conditioned on the per-epoch Zmax artifact quality score:
    noisy EEG epoch (low artifact_weight) -> gate leans toward E4;
    clean EEG (artifact_weight near 1.0)  -> gate leans toward EEG.
    """
    def __init__(self, d_model=S_D_MODEL):
        super().__init__()
        self.gate_fc = nn.Sequential(
            nn.Linear(d_model * 2 + 1, d_model // 2), nn.GELU(),
            nn.Linear(d_model // 2, 1), nn.Sigmoid()
        )

    def forward(self, zmax_embed, e4_embed, artifact_weight):
        aw = artifact_weight.unsqueeze(1)          # (B, 1)
        gate_in = torch.cat([zmax_embed, e4_embed, aw], dim=1)
        gate = self.gate_fc(gate_in)                # (B, 1) in [0,1]
        fused = gate * zmax_embed + (1 - gate) * e4_embed
        return fused, gate


class ArtifactGatedStudentModel(nn.Module):
    def __init__(self, d_model=S_D_MODEL, n_classes=5, dropout=S_DROPOUT):
        super().__init__()
        self.zmax_enc = ZmaxEEGEncoder(in_ch=2, d_model=d_model, dropout=dropout)
        self.e4_enc   = E4Encoder(in_ch=3, d_model=d_model, dropout=dropout)
        self.fusion   = ArtifactGatedFusion(d_model=d_model)
        self.classifier = nn.Sequential(
            nn.LayerNorm(d_model), nn.Linear(d_model, 64), nn.GELU(),
            nn.Dropout(dropout), nn.Linear(64, n_classes)
        )

    def forward(self, zmax_x, e4_x, artifact_weight):
        z = self.zmax_enc(zmax_x)
        e = self.e4_enc(e4_x)
        fused, gate = self.fusion(z, e, artifact_weight)
        logits = self.classifier(fused)
        return logits, gate


# ============================================================
# COMBINED DATASET (now also returns artifact_weight for the gate)
# ============================================================
class KDDataset(Dataset):
    def __init__(self, subject_list, psg_path, student_path, context=CONTEXT):
        self.context = context
        self.data = []
        self.index = []

        skipped_mismatch = 0
        for sub in subject_list:
            psg_fp = os.path.join(psg_path, f"{sub}.npz")
            stu_fp = os.path.join(student_path, f"{sub}.npz")
            if not (os.path.exists(psg_fp) and os.path.exists(stu_fp)):
                continue

            with np.load(psg_fp) as d:
                eeg = d['eeg'][:, [0, 1], :]
                eog = d['eog'][:, [0], :]
                psg_signal = np.concatenate([eeg, eog], axis=1).astype(np.float32)
                psg_labels = d['labels'].copy()

            with np.load(stu_fp) as d:
                zmax_arr = d['zmax_eeg']
                e4_arr   = d['e4']
                stu_labels = d['labels'].copy()
                art_w = d['artifact_weight']

            n = min(len(psg_labels), len(stu_labels))
            if abs(len(psg_labels) - len(stu_labels)) > 5:
                skipped_mismatch += 1

            sub_idx = len(self.data)
            self.data.append((psg_signal, psg_labels, zmax_arr, e4_arr, art_w, stu_labels))
            for i in range(n):
                self.index.append((sub_idx, i, n))

        print(f"  Subjects loaded: {len(self.data)}  (large mismatches: {skipped_mismatch})")
        print(f"  Samples: {len(self.index):,}")

    def __len__(self):
        return len(self.index)

    def __getitem__(self, idx):
        sub_idx, center_i, n = self.index[idx]
        psg_signal, psg_labels, zmax_arr, e4_arr, art_w, stu_labels = self.data[sub_idx]

        window_epochs = []
        for offset in range(-self.context, self.context + 1):
            ei = max(0, min(n - 1, center_i + offset))
            window_epochs.append(psg_signal[ei])
        psg_x = np.stack(window_epochs, axis=0)

        ei = min(center_i, zmax_arr.shape[0] - 1, e4_arr.shape[0] - 1)
        zmax_x = zmax_arr[ei]
        e4_x   = e4_arr[ei]
        aw     = float(art_w[ei]) if ei < len(art_w) else 1.0

        y = int(stu_labels[center_i]) if center_i < len(stu_labels) else int(psg_labels[center_i])

        return (
            torch.FloatTensor(psg_x),
            torch.FloatTensor(zmax_x),
            torch.FloatTensor(e4_x),
            torch.tensor(aw, dtype=torch.float32),
            torch.tensor(y, dtype=torch.long),
        )


# ============================================================
# LOAD SPLIT + BUILD DATASETS
# ============================================================
_train_path = os.path.join(PSG_EEG_PATH, "_train_subs.npy")
_test_path  = os.path.join(PSG_EEG_PATH, "_test_subs.npy")
TRAIN_SUBS = np.load(_train_path, allow_pickle=True).tolist()
TEST_SUBS  = np.load(_test_path,  allow_pickle=True).tolist()
print(f"Split loaded -> Train:{len(TRAIN_SUBS)}  Test:{len(TEST_SUBS)}")

print("\nBuilding KD datasets...")
train_ds = KDDataset(TRAIN_SUBS, PSG_EEG_PATH, STUDENT_DATA_PATH)
print()
test_ds  = KDDataset(TEST_SUBS, PSG_EEG_PATH, STUDENT_DATA_PATH)
print("Datasets ready.")


# ============================================================
# LOAD FROZEN TEACHER ENSEMBLE
# ============================================================
print(f"\nLoading {len(TEACHER_SEEDS)} frozen teacher checkpoints...")
teachers = []
for seed in TEACHER_SEEDS:
    ckpt = os.path.join(TEACHER_CKPT_DIR, f"best_seed{seed}.pt")
    if not os.path.exists(ckpt):
        print(f"  MISSING: {ckpt}")
        continue
    m = MultiScaleSleepNetPlain(in_ch=3).to(device)
    m.load_state_dict(torch.load(ckpt, map_location=device))
    m.eval()
    for p in m.parameters():
        p.requires_grad = False
    teachers.append(m)
print(f"Loaded {len(teachers)} teacher models (frozen).")


@torch.no_grad()
def teacher_soft_targets(psg_x, temperature=KD_TEMPERATURE):
    probs_sum = None
    for m in teachers:
        logits = m(psg_x)
        probs = F.softmax(logits / temperature, dim=1)
        probs_sum = probs if probs_sum is None else probs_sum + probs
    return probs_sum / len(teachers)


# ============================================================
# CLASS WEIGHTS
# ============================================================
all_train_labels = []
for _, _, _, _, _, labs in train_ds.data:
    all_train_labels.extend(labs.tolist())
label_counts = np.array([Counter(all_train_labels).get(i, 1) for i in range(5)], dtype=np.float32)
cw = torch.FloatTensor(label_counts.sum() / (5 * label_counts)).to(device)
print(f"\nClass weights: {dict(zip(LABEL_NAMES, cw.cpu().numpy().round(3)))}")


def set_seed(seed):
    random.seed(seed); np.random.seed(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


def kd_loss_fn(student_logits, teacher_probs, labels, temperature, lam, class_weights):
    """L = L_CE + lambda_KD * L_KD  (plain CE, no artifact-weighted loss -- that's S4)"""
    student_log_probs = F.log_softmax(student_logits / temperature, dim=1)
    kd = F.kl_div(student_log_probs, teacher_probs, reduction='batchmean') * (temperature ** 2)
    ce = F.cross_entropy(student_logits, labels, weight=class_weights)
    total = ce + lam * kd
    return total, kd.item(), ce.item()


def train_epoch(model, loader, optimizer, scheduler):
    model.train()
    total_loss = total_kd = total_ce = 0
    preds, labs_all = [], []
    for psg_x, zmax_x, e4_x, aw, y in loader:
        psg_x, zmax_x, e4_x, aw, y = (
            psg_x.to(device), zmax_x.to(device), e4_x.to(device),
            aw.to(device), y.to(device)
        )
        optimizer.zero_grad()
        teacher_probs = teacher_soft_targets(psg_x)
        student_logits, gate = model(zmax_x, e4_x, aw)
        loss, kd_val, ce_val = kd_loss_fn(
            student_logits, teacher_probs, y, KD_TEMPERATURE, KD_LAMBDA, cw
        )
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()

        total_loss += loss.item(); total_kd += kd_val; total_ce += ce_val
        preds.extend(student_logits.argmax(1).cpu().numpy())
        labs_all.extend(y.cpu().numpy())

    n = len(loader)
    acc = accuracy_score(labs_all, preds)
    f1 = f1_score(labs_all, preds, average='macro', zero_division=0)
    return total_loss / n, total_kd / n, total_ce / n, acc, f1


@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    preds, labs_all, gates_all, aw_all = [], [], [], []
    for psg_x, zmax_x, e4_x, aw, y in loader:
        zmax_x, e4_x, aw = zmax_x.to(device), e4_x.to(device), aw.to(device)
        logits, gate = model(zmax_x, e4_x, aw)
        preds.extend(logits.argmax(1).cpu().numpy())
        labs_all.extend(y.numpy())
        gates_all.extend(gate.cpu().numpy().flatten())
        aw_all.extend(aw.cpu().numpy())
    preds, labs_all = np.array(preds), np.array(labs_all)
    gates_all, aw_all = np.array(gates_all), np.array(aw_all)

    acc = accuracy_score(labs_all, preds)
    f1 = f1_score(labs_all, preds, average='macro', zero_division=0)
    kappa = cohen_kappa_score(labs_all, preds)
    per_cls = f1_score(labs_all, preds, average=None, zero_division=0)

    # Gate behavior check: does the gate actually respond to artifact quality?
    clean_mask = aw_all >= 0.9
    noisy_mask = aw_all < 0.5
    gate_clean = gates_all[clean_mask].mean() if clean_mask.sum() > 0 else float('nan')
    gate_noisy = gates_all[noisy_mask].mean() if noisy_mask.sum() > 0 else float('nan')

    return acc, f1, kappa, per_cls, gates_all.mean(), gate_clean, gate_noisy


# ============================================================
# TRAINING LOOP
# ============================================================
csv_path = os.path.join(EVAL_PATH, "summary.csv")
fields = ["seed", "acc", "f1_macro", "kappa", "f1_Wake", "f1_N1", "f1_N2", "f1_N3", "f1_REM",
          "mean_gate", "gate_clean", "gate_noisy"]
with open(csv_path, 'w', newline='') as f:
    csv.DictWriter(f, fields).writeheader()

all_results = []
for seed_idx, seed in enumerate(SEEDS):
    print(f"\n{'='*60}\nSTUDENT SEED {seed}  ({seed_idx+1}/{len(SEEDS)})\n{'='*60}")
    set_seed(seed)

    train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,
                               num_workers=0, generator=torch.Generator().manual_seed(seed))
    test_loader = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

    model = ArtifactGatedStudentModel().to(device)
    n_params = sum(p.numel() for p in model.parameters())
    print(f"  Student parameters: {n_params:,}  (teacher frozen, not counted)")

    optimizer = optim.AdamW(model.parameters(), lr=5e-4, weight_decay=3e-4, betas=(0.9, 0.98), eps=1e-9)
    total_steps = N_EPOCHS * len(train_loader)
    warmup_steps = int(0.05 * total_steps)

    def warmup_cosine(step):
        if step < warmup_steps:
            return step / max(warmup_steps, 1)
        t = (step - warmup_steps) / max(total_steps - warmup_steps, 1)
        return 0.5 * (1 + math.cos(math.pi * t))

    scheduler = optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=warmup_cosine)

    best_f1 = 0.0
    best_path = os.path.join(EVAL_PATH, f"best_student_seed{seed}.pt")

    for epoch in range(1, N_EPOCHS + 1):
        tr_loss, tr_kd, tr_ce, tr_acc, tr_f1 = train_epoch(model, train_loader, optimizer, scheduler)
        vl_acc, vl_f1, vl_kap, vl_per, mean_gate, gate_clean, gate_noisy = evaluate(model, test_loader)

        saved = ""
        if vl_f1 > best_f1:
            best_f1 = vl_f1
            torch.save(model.state_dict(), best_path)
            saved = " <- BEST"

        print(f"  Ep[{epoch:02d}/{N_EPOCHS}] Loss:{tr_loss:.3f}(CE:{tr_ce:.3f}+KD:{tr_kd:.3f}) "
              f"TrF1:{tr_f1:.3f} ValAcc:{vl_acc:.3f} F1:{vl_f1:.3f} k:{vl_kap:.3f} "
              f"gate(mean/clean/noisy):{mean_gate:.2f}/{gate_clean:.2f}/{gate_noisy:.2f}{saved}")

    model.load_state_dict(torch.load(best_path, map_location=device))
    fin_acc, fin_f1, fin_kap, fin_per, fin_gate, fin_gate_clean, fin_gate_noisy = evaluate(model, test_loader)

    print(f"\n  Seed {seed} FINAL: Acc={fin_acc*100:.2f}% F1={fin_f1:.4f} k={fin_kap:.4f}")
    print(f"  Gate -- mean:{fin_gate:.3f}  on clean epochs:{fin_gate_clean:.3f}  on noisy epochs:{fin_gate_noisy:.3f}")
    print(f"  (gate closer to 1 = trusting EEG more; closer to 0 = trusting E4 more)")
    for i, name in enumerate(LABEL_NAMES):
        print(f"    {name:6s}: {fin_per[i]:.4f}")

    all_results.append({
        'seed': seed, 'acc': fin_acc, 'f1': fin_f1, 'kappa': fin_kap, 'per_cls': fin_per,
        'gate': fin_gate, 'gate_clean': fin_gate_clean, 'gate_noisy': fin_gate_noisy
    })
    with open(csv_path, 'a', newline='') as f:
        csv.DictWriter(f, fields).writerow({
            "seed": seed, "acc": round(fin_acc, 4), "f1_macro": round(fin_f1, 4),
            "kappa": round(fin_kap, 4),
            "f1_Wake": round(fin_per[0], 4), "f1_N1": round(fin_per[1], 4),
            "f1_N2": round(fin_per[2], 4), "f1_N3": round(fin_per[3], 4),
            "f1_REM": round(fin_per[4], 4),
            "mean_gate": round(fin_gate, 4),
            "gate_clean": round(fin_gate_clean, 4), "gate_noisy": round(fin_gate_noisy, 4),
        })

# ============================================================
# FINAL REPORT
# ============================================================
accs = np.array([r['acc'] for r in all_results]) * 100
f1s = np.array([r['f1'] for r in all_results])
kappas = np.array([r['kappa'] for r in all_results])
gates_clean = np.array([r['gate_clean'] for r in all_results])
gates_noisy = np.array([r['gate_noisy'] for r in all_results])

print(f"\n{'='*60}\nS3: ARTIFACT-GATED STUDENT + KD -- 5-SEED REPORT\n{'='*60}")
print(f"Accuracy : {accs.mean():.2f} +- {accs.std():.2f}%")
print(f"Macro F1 : {f1s.mean():.4f} +- {f1s.std():.4f}")
print(f"Kappa    : {kappas.mean():.4f} +- {kappas.std():.4f}")
print(f"Gate on clean epochs : {gates_clean.mean():.3f}")
print(f"Gate on noisy epochs : {gates_noisy.mean():.3f}")

print(f"\n{'='*60}\nCOMPARISON: S1 vs S2 vs S3\n{'='*60}")
print(f"{'Model':<45} {'Acc%':>7} {'F1':>7}")
print("-" * 62)
print(f"{'S1: Wearable baseline (no KD)':<45} {'57.09':>7} {'0.5112':>7}")
print(f"{'S2: KD Student (concat fusion)':<45} {'61.86':>7} {'0.5219':>7}")
print(f"{'S3: KD + artifact-gated fusion (this)':<45} {accs.mean():>7.2f} {f1s.mean():>7.4f}")
print(f"{'Teacher (PSG, reference)':<45} {'85.09':>7} {'0.8126':>7}")
print("=" * 62)

print("\nInterpretation:")
print("  If S3 F1 > S2 F1, artifact-aware gating adds value beyond")
print("  KD alone. Check gate_clean vs gate_noisy above: if the gate")
print("  is meaningfully higher on clean epochs than noisy ones, the")
print("  model has learned to trust EEG less when it's degraded --")
print("  this is the qualitative story for your thesis regardless of")
print("  whether F1 improves further. Next step (S4) tests whether")
print("  ALSO adding artifact-weighted CE loss (on top of the gate)")
print("  helps further, though your PSG ablation suggests this may")
print("  not help and should be treated as an open question, not an")
print("  assumed win.")

print(f"\nSummary saved: {csv_path}")
print("Done!")
# Out:
# Device        : cuda
# S3: Artifact-conditioned gated fusion + KD (no artifact loss weighting yet)
# KD lambda     : 1.0   Temperature: 3.0
# Teacher       : MultiScaleSleepNetPlain, 5-seed ensemble (frozen)
# Student       : ArtifactGatedStudentModel (gate replaces concat)
# Output        : D:\22\AA\evaluation\teacher-student\s3_artifact_gated_kd
# Split loaded -> Train:76  Test:20
#
# Building KD datasets...
#   Subjects loaded: 71  (large mismatches: 0)
#   Samples: 66,763
#
#   Subjects loaded: 19  (large mismatches: 0)
#   Samples: 18,898
# Datasets ready.
#
# Loading 5 frozen teacher checkpoints...
# Loaded 5 teacher models (frozen).
#
# Class weights: {'Wake': np.float32(1.838), 'N1': np.float32(3.149), 'N2': np.float32(0.446), 'N3': np.float32(1.009), 'REM': np.float32(1.107)}
#
# ============================================================
# STUDENT SEED 42  (1/5)
# ============================================================
#   Student parameters: 157,014  (teacher frozen, not counted)
#   Ep[01/30] Loss:7.973(CE:1.575+KD:6.398) TrF1:0.386 ValAcc:0.559 F1:0.412 k:0.316 gate(mean/clean/noisy):0.55/0.57/0.52 <- BEST
#   Ep[02/30] Loss:6.383(CE:1.485+KD:4.898) TrF1:0.493 ValAcc:0.565 F1:0.431 k:0.337 gate(mean/clean/noisy):0.61/0.65/0.55 <- BEST
#   Ep[03/30] Loss:5.754(CE:1.388+KD:4.365) TrF1:0.542 ValAcc:0.562 F1:0.447 k:0.375 gate(mean/clean/noisy):0.58/0.64/0.48 <- BEST
#   Ep[04/30] Loss:5.373(CE:1.319+KD:4.054) TrF1:0.565 ValAcc:0.559 F1:0.470 k:0.371 gate(mean/clean/noisy):0.60/0.67/0.48 <- BEST
#   Ep[05/30] Loss:5.108(CE:1.273+KD:3.835) TrF1:0.589 ValAcc:0.560 F1:0.471 k:0.374 gate(mean/clean/noisy):0.60/0.68/0.48 <- BEST
#   Ep[06/30] Loss:4.831(CE:1.225+KD:3.606) TrF1:0.608 ValAcc:0.561 F1:0.469 k:0.373 gate(mean/clean/noisy):0.62/0.70/0.51
#   Ep[07/30] Loss:4.623(CE:1.186+KD:3.437) TrF1:0.621 ValAcc:0.580 F1:0.482 k:0.387 gate(mean/clean/noisy):0.62/0.71/0.49 <- BEST
#   Ep[08/30] Loss:4.447(CE:1.148+KD:3.299) TrF1:0.634 ValAcc:0.567 F1:0.474 k:0.388 gate(mean/clean/noisy):0.67/0.73/0.57
#   Ep[09/30] Loss:4.297(CE:1.119+KD:3.177) TrF1:0.643 ValAcc:0.570 F1:0.480 k:0.392 gate(mean/clean/noisy):0.65/0.72/0.53
#   Ep[10/30] Loss:4.182(CE:1.102+KD:3.081) TrF1:0.654 ValAcc:0.589 F1:0.490 k:0.395 gate(mean/clean/noisy):0.67/0.75/0.54 <- BEST
#   Ep[11/30] Loss:4.066(CE:1.077+KD:2.989) TrF1:0.660 ValAcc:0.582 F1:0.501 k:0.414 gate(mean/clean/noisy):0.69/0.76/0.58 <- BEST
#   Ep[12/30] Loss:3.956(CE:1.055+KD:2.902) TrF1:0.669 ValAcc:0.577 F1:0.496 k:0.411 gate(mean/clean/noisy):0.68/0.76/0.56
#   Ep[13/30] Loss:3.870(CE:1.032+KD:2.838) TrF1:0.675 ValAcc:0.590 F1:0.507 k:0.422 gate(mean/clean/noisy):0.65/0.73/0.52 <- BEST
#   Ep[14/30] Loss:3.789(CE:1.022+KD:2.767) TrF1:0.680 ValAcc:0.593 F1:0.495 k:0.414 gate(mean/clean/noisy):0.71/0.78/0.59
#   Ep[15/30] Loss:3.689(CE:0.995+KD:2.694) TrF1:0.688 ValAcc:0.590 F1:0.503 k:0.419 gate(mean/clean/noisy):0.68/0.75/0.59
#   Ep[16/30] Loss:3.632(CE:0.984+KD:2.648) TrF1:0.691 ValAcc:0.586 F1:0.504 k:0.417 gate(mean/clean/noisy):0.69/0.77/0.58
#   Ep[17/30] Loss:3.562(CE:0.973+KD:2.589) TrF1:0.692 ValAcc:0.596 F1:0.509 k:0.424 gate(mean/clean/noisy):0.69/0.76/0.59 <- BEST
#   Ep[18/30] Loss:3.479(CE:0.947+KD:2.532) TrF1:0.700 ValAcc:0.590 F1:0.508 k:0.427 gate(mean/clean/noisy):0.68/0.75/0.58
#   Ep[19/30] Loss:3.432(CE:0.941+KD:2.492) TrF1:0.704 ValAcc:0.588 F1:0.511 k:0.412 gate(mean/clean/noisy):0.68/0.75/0.57 <- BEST
#   Ep[20/30] Loss:3.393(CE:0.929+KD:2.464) TrF1:0.709 ValAcc:0.590 F1:0.506 k:0.423 gate(mean/clean/noisy):0.68/0.75/0.58
#   Ep[21/30] Loss:3.341(CE:0.919+KD:2.422) TrF1:0.709 ValAcc:0.593 F1:0.511 k:0.421 gate(mean/clean/noisy):0.68/0.75/0.58
#   Ep[22/30] Loss:3.288(CE:0.904+KD:2.384) TrF1:0.714 ValAcc:0.597 F1:0.510 k:0.422 gate(mean/clean/noisy):0.67/0.73/0.57
#   Ep[23/30] Loss:3.267(CE:0.901+KD:2.365) TrF1:0.718 ValAcc:0.603 F1:0.516 k:0.429 gate(mean/clean/noisy):0.68/0.74/0.58 <- BEST
#   Ep[24/30] Loss:3.246(CE:0.895+KD:2.351) TrF1:0.717 ValAcc:0.602 F1:0.513 k:0.431 gate(mean/clean/noisy):0.67/0.74/0.57
#   Ep[25/30] Loss:3.183(CE:0.879+KD:2.304) TrF1:0.721 ValAcc:0.597 F1:0.520 k:0.430 gate(mean/clean/noisy):0.66/0.73/0.56 <- BEST
#   Ep[26/30] Loss:3.174(CE:0.876+KD:2.297) TrF1:0.722 ValAcc:0.603 F1:0.518 k:0.435 gate(mean/clean/noisy):0.67/0.74/0.57
#   Ep[27/30] Loss:3.157(CE:0.872+KD:2.284) TrF1:0.724 ValAcc:0.611 F1:0.523 k:0.444 gate(mean/clean/noisy):0.67/0.73/0.57 <- BEST
#   Ep[28/30] Loss:3.167(CE:0.877+KD:2.290) TrF1:0.724 ValAcc:0.605 F1:0.518 k:0.434 gate(mean/clean/noisy):0.67/0.73/0.57
#   Ep[29/30] Loss:3.134(CE:0.862+KD:2.273) TrF1:0.723 ValAcc:0.605 F1:0.521 k:0.438 gate(mean/clean/noisy):0.67/0.74/0.58
#   Ep[30/30] Loss:3.141(CE:0.866+KD:2.275) TrF1:0.724 ValAcc:0.606 F1:0.522 k:0.437 gate(mean/clean/noisy):0.67/0.73/0.58
#
#   Seed 42 FINAL: Acc=61.09% F1=0.5231 k=0.4442
#   Gate -- mean:0.668  on clean epochs:0.734  on noisy epochs:0.569
#   (gate closer to 1 = trusting EEG more; closer to 0 = trusting E4 more)
#     Wake  : 0.5183
#     N1    : 0.2335
#     N2    : 0.7068
#     N3    : 0.6162
#     REM   : 0.5408
#
# ============================================================
# STUDENT SEED 123  (2/5)
# ============================================================
#   Student parameters: 157,014  (teacher frozen, not counted)
#   Ep[01/30] Loss:7.986(CE:1.577+KD:6.409) TrF1:0.385 ValAcc:0.527 F1:0.411 k:0.282 gate(mean/clean/noisy):0.52/0.56/0.47 <- BEST
#   Ep[02/30] Loss:6.380(CE:1.495+KD:4.885) TrF1:0.495 ValAcc:0.573 F1:0.451 k:0.355 gate(mean/clean/noisy):0.53/0.59/0.45 <- BEST
#   Ep[03/30] Loss:5.818(CE:1.396+KD:4.421) TrF1:0.534 ValAcc:0.585 F1:0.452 k:0.361 gate(mean/clean/noisy):0.56/0.63/0.46 <- BEST
#   Ep[04/30] Loss:5.428(CE:1.326+KD:4.102) TrF1:0.564 ValAcc:0.590 F1:0.477 k:0.389 gate(mean/clean/noisy):0.53/0.61/0.42 <- BEST
#   Ep[05/30] Loss:5.144(CE:1.280+KD:3.864) TrF1:0.582 ValAcc:0.561 F1:0.457 k:0.361 gate(mean/clean/noisy):0.55/0.63/0.45
#   Ep[06/30] Loss:4.913(CE:1.246+KD:3.667) TrF1:0.605 ValAcc:0.602 F1:0.488 k:0.393 gate(mean/clean/noisy):0.52/0.61/0.39 <- BEST
#   Ep[07/30] Loss:4.707(CE:1.197+KD:3.509) TrF1:0.619 ValAcc:0.600 F1:0.493 k:0.411 gate(mean/clean/noisy):0.57/0.65/0.46 <- BEST
#   Ep[08/30] Loss:4.527(CE:1.164+KD:3.363) TrF1:0.628 ValAcc:0.606 F1:0.489 k:0.408 gate(mean/clean/noisy):0.58/0.67/0.44
#   Ep[09/30] Loss:4.379(CE:1.134+KD:3.244) TrF1:0.641 ValAcc:0.579 F1:0.491 k:0.400 gate(mean/clean/noisy):0.64/0.71/0.53
#   Ep[10/30] Loss:4.252(CE:1.113+KD:3.138) TrF1:0.646 ValAcc:0.585 F1:0.491 k:0.393 gate(mean/clean/noisy):0.61/0.70/0.48
#   Ep[11/30] Loss:4.134(CE:1.087+KD:3.048) TrF1:0.659 ValAcc:0.589 F1:0.494 k:0.406 gate(mean/clean/noisy):0.64/0.71/0.54 <- BEST
#   Ep[12/30] Loss:4.021(CE:1.071+KD:2.950) TrF1:0.664 ValAcc:0.591 F1:0.493 k:0.409 gate(mean/clean/noisy):0.64/0.71/0.54
#   Ep[13/30] Loss:3.934(CE:1.056+KD:2.878) TrF1:0.672 ValAcc:0.604 F1:0.508 k:0.425 gate(mean/clean/noisy):0.65/0.71/0.56 <- BEST
#   Ep[14/30] Loss:3.824(CE:1.030+KD:2.793) TrF1:0.678 ValAcc:0.612 F1:0.513 k:0.426 gate(mean/clean/noisy):0.65/0.71/0.56 <- BEST
#   Ep[15/30] Loss:3.751(CE:1.015+KD:2.735) TrF1:0.682 ValAcc:0.596 F1:0.498 k:0.406 gate(mean/clean/noisy):0.67/0.74/0.58
#   Ep[16/30] Loss:3.683(CE:0.998+KD:2.685) TrF1:0.687 ValAcc:0.596 F1:0.510 k:0.418 gate(mean/clean/noisy):0.63/0.70/0.54
#   Ep[17/30] Loss:3.629(CE:0.986+KD:2.643) TrF1:0.693 ValAcc:0.603 F1:0.511 k:0.430 gate(mean/clean/noisy):0.65/0.72/0.56
#   Ep[18/30] Loss:3.550(CE:0.969+KD:2.581) TrF1:0.693 ValAcc:0.617 F1:0.521 k:0.437 gate(mean/clean/noisy):0.66/0.71/0.57 <- BEST
#   Ep[19/30] Loss:3.496(CE:0.959+KD:2.536) TrF1:0.698 ValAcc:0.597 F1:0.506 k:0.421 gate(mean/clean/noisy):0.66/0.72/0.58
#   Ep[20/30] Loss:3.445(CE:0.943+KD:2.502) TrF1:0.701 ValAcc:0.575 F1:0.491 k:0.393 gate(mean/clean/noisy):0.68/0.73/0.61
#   Ep[21/30] Loss:3.376(CE:0.928+KD:2.449) TrF1:0.709 ValAcc:0.601 F1:0.514 k:0.425 gate(mean/clean/noisy):0.66/0.72/0.57
#   Ep[22/30] Loss:3.338(CE:0.923+KD:2.415) TrF1:0.712 ValAcc:0.597 F1:0.513 k:0.419 gate(mean/clean/noisy):0.65/0.70/0.56
#   Ep[23/30] Loss:3.313(CE:0.915+KD:2.399) TrF1:0.711 ValAcc:0.616 F1:0.521 k:0.437 gate(mean/clean/noisy):0.65/0.70/0.57 <- BEST
#   Ep[24/30] Loss:3.297(CE:0.915+KD:2.382) TrF1:0.713 ValAcc:0.592 F1:0.506 k:0.416 gate(mean/clean/noisy):0.66/0.71/0.57
#   Ep[25/30] Loss:3.242(CE:0.899+KD:2.343) TrF1:0.717 ValAcc:0.599 F1:0.508 k:0.419 gate(mean/clean/noisy):0.66/0.72/0.59
#   Ep[26/30] Loss:3.241(CE:0.899+KD:2.342) TrF1:0.717 ValAcc:0.590 F1:0.504 k:0.408 gate(mean/clean/noisy):0.65/0.71/0.57
#   Ep[27/30] Loss:3.225(CE:0.894+KD:2.331) TrF1:0.720 ValAcc:0.607 F1:0.516 k:0.431 gate(mean/clean/noisy):0.66/0.71/0.58
#   Ep[28/30] Loss:3.203(CE:0.890+KD:2.312) TrF1:0.720 ValAcc:0.600 F1:0.509 k:0.421 gate(mean/clean/noisy):0.66/0.71/0.58
#   Ep[29/30] Loss:3.203(CE:0.889+KD:2.314) TrF1:0.719 ValAcc:0.603 F1:0.514 k:0.426 gate(mean/clean/noisy):0.66/0.71/0.58
#   Ep[30/30] Loss:3.189(CE:0.884+KD:2.306) TrF1:0.722 ValAcc:0.609 F1:0.518 k:0.433 gate(mean/clean/noisy):0.66/0.71/0.57
#
#   Seed 123 FINAL: Acc=61.59% F1=0.5210 k=0.4369
#   Gate -- mean:0.647  on clean epochs:0.700  on noisy epochs:0.569
#   (gate closer to 1 = trusting EEG more; closer to 0 = trusting E4 more)
#     Wake  : 0.5099
#     N1    : 0.2362
#     N2    : 0.7112
#     N3    : 0.5889
#     REM   : 0.5587
#
# ============================================================
# STUDENT SEED 256  (3/5)
# ============================================================
#   Student parameters: 157,014  (teacher frozen, not counted)
#   Ep[01/30] Loss:7.895(CE:1.600+KD:6.295) TrF1:0.387 ValAcc:0.540 F1:0.405 k:0.296 gate(mean/clean/noisy):0.52/0.54/0.49 <- BEST
#   Ep[02/30] Loss:6.470(CE:1.507+KD:4.963) TrF1:0.491 ValAcc:0.566 F1:0.439 k:0.334 gate(mean/clean/noisy):0.51/0.55/0.45 <- BEST
#   Ep[03/30] Loss:5.903(CE:1.417+KD:4.487) TrF1:0.530 ValAcc:0.575 F1:0.445 k:0.361 gate(mean/clean/noisy):0.53/0.58/0.44 <- BEST
#   Ep[04/30] Loss:5.453(CE:1.338+KD:4.115) TrF1:0.562 ValAcc:0.507 F1:0.386 k:0.260 gate(mean/clean/noisy):0.42/0.49/0.33
#   Ep[05/30] Loss:5.136(CE:1.280+KD:3.857) TrF1:0.585 ValAcc:0.575 F1:0.460 k:0.361 gate(mean/clean/noisy):0.55/0.63/0.43 <- BEST
#   Ep[06/30] Loss:4.915(CE:1.233+KD:3.682) TrF1:0.600 ValAcc:0.583 F1:0.484 k:0.389 gate(mean/clean/noisy):0.57/0.66/0.44 <- BEST
#   Ep[07/30] Loss:4.698(CE:1.202+KD:3.496) TrF1:0.616 ValAcc:0.590 F1:0.482 k:0.393 gate(mean/clean/noisy):0.55/0.65/0.40
#   Ep[08/30] Loss:4.539(CE:1.164+KD:3.376) TrF1:0.627 ValAcc:0.580 F1:0.486 k:0.394 gate(mean/clean/noisy):0.56/0.68/0.39 <- BEST
#   Ep[09/30] Loss:4.396(CE:1.143+KD:3.253) TrF1:0.639 ValAcc:0.561 F1:0.473 k:0.384 gate(mean/clean/noisy):0.58/0.67/0.44
#   Ep[10/30] Loss:4.252(CE:1.105+KD:3.147) TrF1:0.646 ValAcc:0.545 F1:0.462 k:0.370 gate(mean/clean/noisy):0.60/0.70/0.44
#   Ep[11/30] Loss:4.148(CE:1.094+KD:3.054) TrF1:0.654 ValAcc:0.583 F1:0.480 k:0.399 gate(mean/clean/noisy):0.61/0.71/0.45
#   Ep[12/30] Loss:4.022(CE:1.069+KD:2.952) TrF1:0.665 ValAcc:0.570 F1:0.494 k:0.401 gate(mean/clean/noisy):0.60/0.70/0.45 <- BEST
#   Ep[13/30] Loss:3.949(CE:1.047+KD:2.902) TrF1:0.671 ValAcc:0.587 F1:0.508 k:0.408 gate(mean/clean/noisy):0.63/0.73/0.48 <- BEST
#   Ep[14/30] Loss:3.864(CE:1.036+KD:2.828) TrF1:0.675 ValAcc:0.584 F1:0.506 k:0.412 gate(mean/clean/noisy):0.63/0.72/0.50
#   Ep[15/30] Loss:3.761(CE:1.008+KD:2.752) TrF1:0.682 ValAcc:0.595 F1:0.503 k:0.418 gate(mean/clean/noisy):0.62/0.71/0.48
#   Ep[16/30] Loss:3.719(CE:1.005+KD:2.713) TrF1:0.686 ValAcc:0.585 F1:0.504 k:0.413 gate(mean/clean/noisy):0.59/0.70/0.44
#   Ep[17/30] Loss:3.651(CE:0.984+KD:2.667) TrF1:0.693 ValAcc:0.570 F1:0.503 k:0.401 gate(mean/clean/noisy):0.62/0.71/0.50
#   Ep[18/30] Loss:3.598(CE:0.978+KD:2.620) TrF1:0.697 ValAcc:0.571 F1:0.492 k:0.398 gate(mean/clean/noisy):0.61/0.71/0.47
#   Ep[19/30] Loss:3.532(CE:0.961+KD:2.571) TrF1:0.701 ValAcc:0.532 F1:0.467 k:0.347 gate(mean/clean/noisy):0.61/0.70/0.49
#   Ep[20/30] Loss:3.507(CE:0.959+KD:2.548) TrF1:0.700 ValAcc:0.580 F1:0.498 k:0.404 gate(mean/clean/noisy):0.63/0.72/0.49
#   Ep[21/30] Loss:3.455(CE:0.946+KD:2.508) TrF1:0.703 ValAcc:0.586 F1:0.502 k:0.409 gate(mean/clean/noisy):0.65/0.73/0.51
#   Ep[22/30] Loss:3.405(CE:0.932+KD:2.473) TrF1:0.708 ValAcc:0.566 F1:0.492 k:0.389 gate(mean/clean/noisy):0.64/0.72/0.51
#   Ep[23/30] Loss:3.381(CE:0.926+KD:2.455) TrF1:0.710 ValAcc:0.582 F1:0.505 k:0.412 gate(mean/clean/noisy):0.62/0.71/0.49
#   Ep[24/30] Loss:3.351(CE:0.925+KD:2.426) TrF1:0.711 ValAcc:0.579 F1:0.503 k:0.408 gate(mean/clean/noisy):0.63/0.72/0.50
#   Ep[25/30] Loss:3.318(CE:0.914+KD:2.404) TrF1:0.716 ValAcc:0.588 F1:0.506 k:0.418 gate(mean/clean/noisy):0.63/0.71/0.50
#   Ep[26/30] Loss:3.300(CE:0.913+KD:2.387) TrF1:0.715 ValAcc:0.594 F1:0.512 k:0.423 gate(mean/clean/noisy):0.63/0.72/0.51 <- BEST
#   Ep[27/30] Loss:3.285(CE:0.904+KD:2.381) TrF1:0.717 ValAcc:0.587 F1:0.506 k:0.415 gate(mean/clean/noisy):0.63/0.73/0.50
#   Ep[28/30] Loss:3.265(CE:0.900+KD:2.365) TrF1:0.718 ValAcc:0.594 F1:0.512 k:0.424 gate(mean/clean/noisy):0.64/0.72/0.51 <- BEST
#   Ep[29/30] Loss:3.263(CE:0.898+KD:2.366) TrF1:0.720 ValAcc:0.579 F1:0.503 k:0.408 gate(mean/clean/noisy):0.64/0.72/0.51
#   Ep[30/30] Loss:3.248(CE:0.892+KD:2.356) TrF1:0.718 ValAcc:0.583 F1:0.503 k:0.410 gate(mean/clean/noisy):0.64/0.72/0.50
#
#   Seed 256 FINAL: Acc=59.36% F1=0.5124 k=0.4235
#   Gate -- mean:0.638  on clean epochs:0.725  on noisy epochs:0.507
#   (gate closer to 1 = trusting EEG more; closer to 0 = trusting E4 more)
#     Wake  : 0.5261
#     N1    : 0.2278
#     N2    : 0.6791
#     N3    : 0.5795
#     REM   : 0.5498
#
# ============================================================
# STUDENT SEED 789  (4/5)
# ============================================================
#   Student parameters: 157,014  (teacher frozen, not counted)
#   Ep[01/30] Loss:7.985(CE:1.584+KD:6.400) TrF1:0.373 ValAcc:0.527 F1:0.425 k:0.306 gate(mean/clean/noisy):0.47/0.50/0.44 <- BEST
#   Ep[02/30] Loss:6.402(CE:1.490+KD:4.912) TrF1:0.492 ValAcc:0.557 F1:0.440 k:0.330 gate(mean/clean/noisy):0.53/0.59/0.43 <- BEST
#   Ep[03/30] Loss:5.779(CE:1.393+KD:4.386) TrF1:0.535 ValAcc:0.552 F1:0.461 k:0.347 gate(mean/clean/noisy):0.55/0.61/0.47 <- BEST
#   Ep[04/30] Loss:5.369(CE:1.319+KD:4.050) TrF1:0.571 ValAcc:0.554 F1:0.455 k:0.355 gate(mean/clean/noisy):0.56/0.64/0.44
#   Ep[05/30] Loss:5.038(CE:1.257+KD:3.781) TrF1:0.591 ValAcc:0.595 F1:0.484 k:0.392 gate(mean/clean/noisy):0.56/0.65/0.42 <- BEST
#   Ep[06/30] Loss:4.789(CE:1.207+KD:3.582) TrF1:0.607 ValAcc:0.570 F1:0.481 k:0.378 gate(mean/clean/noisy):0.59/0.67/0.48
#   Ep[07/30] Loss:4.636(CE:1.184+KD:3.452) TrF1:0.618 ValAcc:0.576 F1:0.483 k:0.383 gate(mean/clean/noisy):0.61/0.71/0.46
#   Ep[08/30] Loss:4.460(CE:1.148+KD:3.312) TrF1:0.632 ValAcc:0.588 F1:0.488 k:0.392 gate(mean/clean/noisy):0.62/0.70/0.49 <- BEST
#   Ep[09/30] Loss:4.312(CE:1.118+KD:3.194) TrF1:0.641 ValAcc:0.594 F1:0.495 k:0.405 gate(mean/clean/noisy):0.64/0.72/0.53 <- BEST
#   Ep[10/30] Loss:4.203(CE:1.106+KD:3.097) TrF1:0.653 ValAcc:0.589 F1:0.496 k:0.409 gate(mean/clean/noisy):0.61/0.70/0.48 <- BEST
#   Ep[11/30] Loss:4.067(CE:1.070+KD:2.996) TrF1:0.659 ValAcc:0.598 F1:0.507 k:0.410 gate(mean/clean/noisy):0.62/0.71/0.48 <- BEST
#   Ep[12/30] Loss:3.979(CE:1.051+KD:2.928) TrF1:0.669 ValAcc:0.584 F1:0.495 k:0.398 gate(mean/clean/noisy):0.62/0.70/0.49
#   Ep[13/30] Loss:3.872(CE:1.034+KD:2.838) TrF1:0.673 ValAcc:0.603 F1:0.511 k:0.422 gate(mean/clean/noisy):0.62/0.69/0.51 <- BEST
#   Ep[14/30] Loss:3.766(CE:1.011+KD:2.755) TrF1:0.680 ValAcc:0.583 F1:0.501 k:0.405 gate(mean/clean/noisy):0.65/0.72/0.54
#   Ep[15/30] Loss:3.721(CE:1.001+KD:2.720) TrF1:0.683 ValAcc:0.600 F1:0.511 k:0.421 gate(mean/clean/noisy):0.62/0.69/0.51 <- BEST
#   Ep[16/30] Loss:3.646(CE:0.990+KD:2.657) TrF1:0.688 ValAcc:0.604 F1:0.515 k:0.429 gate(mean/clean/noisy):0.65/0.71/0.56 <- BEST
#   Ep[17/30] Loss:3.578(CE:0.973+KD:2.605) TrF1:0.693 ValAcc:0.585 F1:0.500 k:0.402 gate(mean/clean/noisy):0.64/0.70/0.54
#   Ep[18/30] Loss:3.525(CE:0.957+KD:2.568) TrF1:0.697 ValAcc:0.586 F1:0.505 k:0.412 gate(mean/clean/noisy):0.64/0.69/0.56
#   Ep[19/30] Loss:3.457(CE:0.942+KD:2.515) TrF1:0.699 ValAcc:0.604 F1:0.518 k:0.433 gate(mean/clean/noisy):0.65/0.71/0.57 <- BEST
#   Ep[20/30] Loss:3.417(CE:0.933+KD:2.483) TrF1:0.705 ValAcc:0.608 F1:0.519 k:0.435 gate(mean/clean/noisy):0.64/0.71/0.55 <- BEST
#   Ep[21/30] Loss:3.372(CE:0.929+KD:2.443) TrF1:0.708 ValAcc:0.591 F1:0.498 k:0.403 gate(mean/clean/noisy):0.65/0.71/0.57
#   Ep[22/30] Loss:3.339(CE:0.918+KD:2.422) TrF1:0.710 ValAcc:0.584 F1:0.500 k:0.401 gate(mean/clean/noisy):0.66/0.72/0.59
#   Ep[23/30] Loss:3.284(CE:0.902+KD:2.382) TrF1:0.713 ValAcc:0.589 F1:0.501 k:0.406 gate(mean/clean/noisy):0.65/0.71/0.57
#   Ep[24/30] Loss:3.261(CE:0.902+KD:2.360) TrF1:0.716 ValAcc:0.599 F1:0.505 k:0.418 gate(mean/clean/noisy):0.66/0.71/0.60
#   Ep[25/30] Loss:3.232(CE:0.893+KD:2.339) TrF1:0.717 ValAcc:0.598 F1:0.509 k:0.424 gate(mean/clean/noisy):0.67/0.72/0.60
#   Ep[26/30] Loss:3.212(CE:0.889+KD:2.323) TrF1:0.717 ValAcc:0.601 F1:0.512 k:0.427 gate(mean/clean/noisy):0.67/0.72/0.60
#   Ep[27/30] Loss:3.185(CE:0.881+KD:2.305) TrF1:0.721 ValAcc:0.598 F1:0.508 k:0.418 gate(mean/clean/noisy):0.67/0.72/0.60
#   Ep[28/30] Loss:3.197(CE:0.885+KD:2.311) TrF1:0.718 ValAcc:0.602 F1:0.510 k:0.420 gate(mean/clean/noisy):0.66/0.71/0.59
#   Ep[29/30] Loss:3.185(CE:0.880+KD:2.305) TrF1:0.720 ValAcc:0.594 F1:0.507 k:0.414 gate(mean/clean/noisy):0.66/0.70/0.59
#   Ep[30/30] Loss:3.169(CE:0.873+KD:2.296) TrF1:0.720 ValAcc:0.601 F1:0.512 k:0.426 gate(mean/clean/noisy):0.67/0.71/0.59
#
#   Seed 789 FINAL: Acc=60.85% F1=0.5190 k=0.4351
#   Gate -- mean:0.644  on clean epochs:0.707  on noisy epochs:0.550
#   (gate closer to 1 = trusting EEG more; closer to 0 = trusting E4 more)
#     Wake  : 0.5310
#     N1    : 0.2206
#     N2    : 0.6956
#     N3    : 0.5975
#     REM   : 0.5505
#
# ============================================================
# STUDENT SEED 999  (5/5)
# ============================================================
#   Student parameters: 157,014  (teacher frozen, not counted)
#   Ep[01/30] Loss:7.845(CE:1.584+KD:6.261) TrF1:0.389 ValAcc:0.540 F1:0.411 k:0.315 gate(mean/clean/noisy):0.55/0.57/0.51 <- BEST
#   Ep[02/30] Loss:6.444(CE:1.503+KD:4.941) TrF1:0.488 ValAcc:0.568 F1:0.447 k:0.348 gate(mean/clean/noisy):0.53/0.57/0.46 <- BEST
#   Ep[03/30] Loss:5.845(CE:1.403+KD:4.442) TrF1:0.532 ValAcc:0.534 F1:0.444 k:0.325 gate(mean/clean/noisy):0.50/0.57/0.40
#   Ep[04/30] Loss:5.433(CE:1.333+KD:4.100) TrF1:0.564 ValAcc:0.581 F1:0.471 k:0.390 gate(mean/clean/noisy):0.52/0.60/0.40 <- BEST
#   Ep[05/30] Loss:5.087(CE:1.264+KD:3.824) TrF1:0.591 ValAcc:0.576 F1:0.476 k:0.390 gate(mean/clean/noisy):0.58/0.65/0.47 <- BEST
#   Ep[06/30] Loss:4.844(CE:1.229+KD:3.615) TrF1:0.606 ValAcc:0.588 F1:0.499 k:0.402 gate(mean/clean/noisy):0.57/0.64/0.46 <- BEST
#   Ep[07/30] Loss:4.623(CE:1.186+KD:3.437) TrF1:0.621 ValAcc:0.587 F1:0.496 k:0.403 gate(mean/clean/noisy):0.59/0.67/0.47
#   Ep[08/30] Loss:4.449(CE:1.155+KD:3.294) TrF1:0.635 ValAcc:0.584 F1:0.497 k:0.400 gate(mean/clean/noisy):0.57/0.67/0.43
#   Ep[09/30] Loss:4.322(CE:1.129+KD:3.193) TrF1:0.641 ValAcc:0.575 F1:0.497 k:0.400 gate(mean/clean/noisy):0.60/0.69/0.47
#   Ep[10/30] Loss:4.203(CE:1.105+KD:3.098) TrF1:0.650 ValAcc:0.584 F1:0.511 k:0.420 gate(mean/clean/noisy):0.61/0.69/0.48 <- BEST
#   Ep[11/30] Loss:4.071(CE:1.080+KD:2.991) TrF1:0.661 ValAcc:0.582 F1:0.500 k:0.404 gate(mean/clean/noisy):0.59/0.68/0.46
#   Ep[12/30] Loss:3.960(CE:1.057+KD:2.903) TrF1:0.667 ValAcc:0.593 F1:0.503 k:0.424 gate(mean/clean/noisy):0.62/0.70/0.49
#   Ep[13/30] Loss:3.881(CE:1.038+KD:2.843) TrF1:0.674 ValAcc:0.602 F1:0.509 k:0.427 gate(mean/clean/noisy):0.64/0.71/0.53
#   Ep[14/30] Loss:3.792(CE:1.019+KD:2.773) TrF1:0.680 ValAcc:0.592 F1:0.511 k:0.431 gate(mean/clean/noisy):0.62/0.69/0.50 <- BEST
#   Ep[15/30] Loss:3.699(CE:1.002+KD:2.697) TrF1:0.685 ValAcc:0.585 F1:0.504 k:0.409 gate(mean/clean/noisy):0.60/0.69/0.48
#   Ep[16/30] Loss:3.662(CE:0.993+KD:2.669) TrF1:0.688 ValAcc:0.591 F1:0.505 k:0.419 gate(mean/clean/noisy):0.64/0.72/0.53
#   Ep[17/30] Loss:3.575(CE:0.975+KD:2.600) TrF1:0.694 ValAcc:0.581 F1:0.506 k:0.406 gate(mean/clean/noisy):0.62/0.70/0.51
#   Ep[18/30] Loss:3.505(CE:0.956+KD:2.549) TrF1:0.697 ValAcc:0.596 F1:0.510 k:0.422 gate(mean/clean/noisy):0.63/0.70/0.52
#   Ep[19/30] Loss:3.464(CE:0.952+KD:2.512) TrF1:0.701 ValAcc:0.594 F1:0.511 k:0.422 gate(mean/clean/noisy):0.64/0.72/0.52
#   Ep[20/30] Loss:3.395(CE:0.935+KD:2.459) TrF1:0.706 ValAcc:0.595 F1:0.507 k:0.417 gate(mean/clean/noisy):0.63/0.70/0.52
#   Ep[21/30] Loss:3.371(CE:0.926+KD:2.445) TrF1:0.706 ValAcc:0.595 F1:0.508 k:0.423 gate(mean/clean/noisy):0.64/0.71/0.54
#   Ep[22/30] Loss:3.319(CE:0.918+KD:2.401) TrF1:0.713 ValAcc:0.583 F1:0.505 k:0.408 gate(mean/clean/noisy):0.64/0.71/0.53
#   Ep[23/30] Loss:3.287(CE:0.907+KD:2.380) TrF1:0.714 ValAcc:0.601 F1:0.517 k:0.429 gate(mean/clean/noisy):0.63/0.71/0.52 <- BEST
#   Ep[24/30] Loss:3.244(CE:0.901+KD:2.344) TrF1:0.717 ValAcc:0.590 F1:0.507 k:0.417 gate(mean/clean/noisy):0.64/0.71/0.53
#   Ep[25/30] Loss:3.232(CE:0.894+KD:2.339) TrF1:0.718 ValAcc:0.581 F1:0.501 k:0.408 gate(mean/clean/noisy):0.63/0.70/0.52
#   Ep[26/30] Loss:3.213(CE:0.887+KD:2.326) TrF1:0.720 ValAcc:0.596 F1:0.509 k:0.422 gate(mean/clean/noisy):0.64/0.71/0.53
#   Ep[27/30] Loss:3.181(CE:0.881+KD:2.300) TrF1:0.722 ValAcc:0.596 F1:0.514 k:0.424 gate(mean/clean/noisy):0.64/0.71/0.54
#   Ep[28/30] Loss:3.174(CE:0.879+KD:2.295) TrF1:0.721 ValAcc:0.596 F1:0.514 k:0.423 gate(mean/clean/noisy):0.64/0.71/0.54
#   Ep[29/30] Loss:3.181(CE:0.882+KD:2.298) TrF1:0.721 ValAcc:0.597 F1:0.513 k:0.424 gate(mean/clean/noisy):0.64/0.71/0.53
#   Ep[30/30] Loss:3.166(CE:0.878+KD:2.288) TrF1:0.725 ValAcc:0.590 F1:0.511 k:0.417 gate(mean/clean/noisy):0.64/0.71/0.54
#
#   Seed 999 FINAL: Acc=60.05% F1=0.5170 k=0.4292
#   Gate -- mean:0.635  on clean epochs:0.709  on noisy epochs:0.524
#   (gate closer to 1 = trusting EEG more; closer to 0 = trusting E4 more)
#     Wake  : 0.5101
#     N1    : 0.2440
#     N2    : 0.6913
#     N3    : 0.5787
#     REM   : 0.5611
#
# ============================================================
# S3: ARTIFACT-GATED STUDENT + KD -- 5-SEED REPORT
# ============================================================
# Accuracy : 60.59 +- 0.79%
# Macro F1 : 0.5185 +- 0.0036
# Kappa    : 0.4338 +- 0.0070
# Gate on clean epochs : 0.715
# Gate on noisy epochs : 0.544
#
# ============================================================
# COMPARISON: S1 vs S2 vs S3
# ============================================================
# Model                                            Acc%      F1
# --------------------------------------------------------------
# S1: Wearable baseline (no KD)                   57.09  0.5112
# S2: KD Student (concat fusion)                  61.86  0.5219
# S3: KD + artifact-gated fusion (this)           60.59  0.5185
# Teacher (PSG, reference)                        85.09  0.8126
# ==============================================================
#
# Interpretation:
#   If S3 F1 > S2 F1, artifact-aware gating adds value beyond
#   KD alone. Check gate_clean vs gate_noisy above: if the gate
#   is meaningfully higher on clean epochs than noisy ones, the
#   model has learned to trust EEG less when it's degraded --
#   this is the qualitative story for your thesis regardless of
#   whether F1 improves further. Next step (S4) tests whether
#   ALSO adding artifact-weighted CE loss (on top of the gate)
#   helps further, though your PSG ablation suggests this may
#   not help and should be treated as an open question, not an
#   assumed win.
#
# Summary saved: D:\22\AA\evaluation\teacher-student\s3_artifact_gated_kd\summary.csv
# Done!
